# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import requests 
import json
import ijson
import duckdb
from rapidfuzz import process, fuzz
import matplotlib.pyplot as plt

# %% [markdown]
# # LittleSis

# %% [markdown]
# ## Functions

# %%
# Function to fetch entities by a list of IDs
def get_entities_LS(entity_ids_list):
    json_file = "entities.json"
    entity_ids_list = set(entity_ids_list)  # Convert to set for fast lookup
    

    with open(json_file, "r", encoding="utf-8") as file:
        json_data = json.load(file)

        if isinstance(json_data, list):
            filtered_data= pd.DataFrame()

            for entity in json_data:
                if entity.get("attributes").get("id") in entity_ids_list:
                    attributes = entity.get("attributes")
                    entity_info = {
                            "ID": attributes.get("id"),
                            "Name": attributes.get("name"),
                            "Aliases":';'.join( attributes.get("aliases")),
                            "Type": attributes.get("primary_ext"),
                            "Types_other":'; '.join(attributes.get("types")),
                            "Description": attributes.get("blurb"),
                            "Updated": attributes.get("updated_at"),
                            "Links": entity.get("links").get("self"),
                            "Source":"Littlesis"
                        }   
                    new_row = pd.DataFrame([entity_info])
                    filtered_data = pd.concat([filtered_data,new_row], ignore_index=True).drop_duplicates(subset="ID", keep="last")
        else:
            print("Invalid JSON format: Expected a list of entities.")
            return filtered_data # Return empty DataFrame if invalid format
        
    # Return results in Pandas DataFrame
    return filtered_data

# %%
# Merge 2 Dataframes - adding unique rows only
def add_to_df(source, extension):
    return pd.concat([source,extension], ignore_index=True).drop_duplicates(subset="ID", keep="last")

# %%
def get_relationships_LS(entity_ids, related_entities=None, rel_categories=None, json_file="relationships.json"):

    entity_ids = set(entity_ids)
    if related_entities is None:
        related_entities = set()  # Use a set for fast lookups

    related_entities.update(entity_ids if isinstance(entity_ids, set) else {entity_ids}) 

    # Mapping relationship category IDs to descriptions
    rel_category_mapping = {
        1: "Position", 2: "Education", 3: "Membership", 4: "Family", 5: "Donation/Grant",
        6: "Service/Transaction", 7: "Lobbying", 8: "Social", 9: "Professional", 10: "Ownership",
        11: "Hierarchy", 12: "Generic"
    }

    filtered_relationships = []  # Store results efficiently

    with open(json_file, "r", encoding="utf-8") as file:
        objects = ijson.items(file, "item")  # Streaming JSON parser
        
        for rel in objects:
            attributes = rel.get("attributes", {})
            category_id = attributes.get("category_id")
            category_attributes = attributes.get("category_attributes")
            
            # Check category filter (if provided)
            if rel_categories and category_id not in rel_categories:
                continue

            entity1_id, entity2_id = attributes.get("entity1_id"), attributes.get("entity2_id")

            # Ensure we are selecting only relationships for the target entity
            if entity1_id not in entity_ids and entity2_id not in entity_ids:
               continue

            # Identify the related entity (not the source entity)
            related_entity_id = entity2_id if entity1_id in entity_ids else entity1_id
            related_entities.add(related_entity_id) 

            # Store relationship data in a dictionary
            filtered_relationships.append({
                "ID": rel.get("id"),
                "Entity1_ID": entity1_id,
                "Entity2_ID": entity2_id,
                "Category_ID": category_id,
                "Category_desc": rel_category_mapping.get(category_id, "Unknown"),
                "Description": attributes.get("description"),
                "Description_1": attributes.get("description1"),
                "Description_2": attributes.get("description2"),
                "is_current": attributes.get("is_current"),
                "is_board": category_attributes.get("is_board", "")if isinstance(category_attributes, dict) else "",
                "is_executive": category_attributes.get("is_executive", "")if isinstance(category_attributes, dict) else "",
                "is_employee": category_attributes.get("is_employee", "")if isinstance(category_attributes, dict) else "",
                "amount": attributes.get("amount"),
                "currency": attributes.get("currency"),
                "Start_date": attributes.get("start_date"),
                "End_date": attributes.get("end_date"),
                "Updated": attributes.get("updated_at"),
                "Link": rel.get("self"),
            })

    # Convert the list of relationships into a DataFrame efficiently
    return pd.DataFrame(filtered_relationships)

# %%
"""# Getting relationship + related IDs
def get_relationships(entity_id,entity_id_list):
    url = f"https://littlesis.org/api/entities/{entity_id}/relationships"  # API URL for entity data
    response = requests.get(url)
    json_data = response.json()

    if entity_id_list is None:
        entity_id_list = []  # Initialize a new list if no argument is passed
        
    #page count
    currentPage=1
    lastPage = json_data.get("meta").get("pageCount")

    relationship_id_list = []
    entity_id_list.append(entity_id) #create list of IDs + add source ID
    filtered_data = pd.DataFrame()


    list_item = 0
    rel_category_mapping = {
        1: "Position",
        2: "Education",
        3: "Membership",
        4: "Family",
        5: "Donation/Grant",
        6: "Service/Transaction",
        7: "Lobbying",
        8: "Social",
        9: "Professional",
        10: "Ownership",
        11: "Hierarchy",
        12: "Generic"
    }
 
    
    while currentPage <= lastPage:  # go through all pages
        url = f"https://littlesis.org/api/entities/{entity_id}/relationships?page={currentPage}"
        response = requests.get(url)
        json_data = response.json()

        ######################       
        currentPage += 1
        list_item += 1
        ######################

        for rel in json_data.get("data"): #iterating relationships on 1 page
            if rel.get("id") not in relationship_id_list:
                relationship_id_list.append(rel.get("id"))

                entity1_id = rel.get("attributes").get("entity1_id") 
                entity2_id = rel.get("attributes").get("entity2_id") 
                category_attributes = rel.get("attributes").get("category_attributes")

                #add only related id (not soruce)
                if entity1_id == entity_id: 
                    entity_id_list.append(entity2_id)
                else:
                    entity_id_list.append(entity1_id)

                
                relationship_info = {
                    "ID":rel.get("id"),
                    "Entity1_ID": rel.get("attributes").get("entity1_id"),
                    "Entity2_ID": rel.get("attributes").get("entity2_id"),
                    "Category_ID": rel.get("attributes").get("category_id") ,
                    "Category_desc": rel_category_mapping.get(rel.get("attributes").get("category_id")) ,
                    "Description": rel.get("attributes").get("description"),
                    "Description_1": rel.get("attributes").get("description1"),
                    "Description_2": rel.get("attributes").get("description2"),
                    "is_current": rel.get("attributes").get("is_current"),
                    "is_board": rel.get("attributes").get("category_attributes").get("is_board") if isinstance(category_attributes, dict) else "",
                    "is_executive": rel.get("attributes").get("category_attributes").get("is_executive") if isinstance(category_attributes, dict) else "",
                    "is_employee":rel.get("attributes").get("category_attributes").get("is_employee") if isinstance(category_attributes, dict) else "",
                    "amount":rel.get("attributes").get("amount"),
                    "currency":rel.get("attributes").get("currency"),
                    "Start_date":rel.get("attributes").get("start_date"),
                    "End_date": rel.get("attributes").get("end_date"),
                    "Updated": rel.get("attributes").get("updated_at"),
                    "Link": rel.get("self") ,
                }

                new_row = pd.DataFrame([relationship_info])
                filtered_data = pd.concat([filtered_data,new_row], ignore_index=True).drop_duplicates(subset="ID", keep="last")
            else: continue
    entity_id_list[:] = list(set(entity_id_list))# unique related IDs

    # Return results in Pandas DataFrame
    return filtered_data
"""
# Out:
# '# Getting relationship + related IDs\ndef get_relationships(entity_id,entity_id_list):\n    url = f"https://littlesis.org/api/entities/{entity_id}/relationships"  # API URL for entity data\n    response = requests.get(url)\n    json_data = response.json()\n\n    if entity_id_list is None:\n        entity_id_list = []  # Initialize a new list if no argument is passed\n        \n    #page count\n    currentPage=1\n    lastPage = json_data.get("meta").get("pageCount")\n\n    relationship_id_list = []\n    entity_id_list.append(entity_id) #create list of IDs + add source ID\n    filtered_data = pd.DataFrame()\n\n\n    list_item = 0\n    rel_category_mapping = {\n        1: "Position",\n        2: "Education",\n        3: "Membership",\n        4: "Family",\n        5: "Donation/Grant",\n        6: "Service/Transaction",\n        7: "Lobbying",\n        8: "Social",\n        9: "Professional",\n        10: "Ownership",\n        11: "Hierarchy",\n        12: "Generic"\n    }\n \n    \n    while currentPage <= lastPage:  # go through all pages\n        url = f"https://littlesis.org/api/entities/{entity_id}/relationships?page={currentPage}"\n        response = requests.get(url)\n        json_data = response.json()\n\n        ######################       \n        currentPage += 1\n        list_item += 1\n        ######################\n\n        for rel in json_data.get("data"): #iterating relationships on 1 page\n            if rel.get("id") not in relationship_id_list:\n                relationship_id_list.append(rel.get("id"))\n\n                entity1_id = rel.get("attributes").get("entity1_id") \n                entity2_id = rel.get("attributes").get("entity2_id") \n                category_attributes = rel.get("attributes").get("category_attributes")\n\n                #add only related id (not soruce)\n                if entity1_id == entity_id: \n                    entity_id_list.append(entity2_id)\n                else:\n                    entity_id_list.append(entity1_id)\n\n                \n                relationship_info = {\n                    "ID":rel.get("id"),\n                    "Entity1_ID": rel.get("attributes").get("entity1_id"),\n                    "Entity2_ID": rel.get("attributes").get("entity2_id"),\n                    "Category_ID": rel.get("attributes").get("category_id") ,\n                    "Category_desc": rel_category_mapping.get(rel.get("attributes").get("category_id")) ,\n                    "Description": rel.get("attributes").get("description"),\n                    "Description_1": rel.get("attributes").get("description1"),\n                    "Description_2": rel.get("attributes").get("description2"),\n                    "is_current": rel.get("attributes").get("is_current"),\n                    "is_board": rel.get("attributes").get("category_attributes").get("is_board") if isinstance(category_attributes, dict) else "",\n                    "is_executive": rel.get("attributes").get("category_attributes").get("is_executive") if isinstance(category_attributes, dict) else "",\n                    "is_employee":rel.get("attributes").get("category_attributes").get("is_employee") if isinstance(category_attributes, dict) else "",\n                    "amount":rel.get("attributes").get("amount"),\n                    "currency":rel.get("attributes").get("currency"),\n                    "Start_date":rel.get("attributes").get("start_date"),\n                    "End_date": rel.get("attributes").get("end_date"),\n                    "Updated": rel.get("attributes").get("updated_at"),\n                    "Link": rel.get("self") ,\n                }\n\n                new_row = pd.DataFrame([relationship_info])\n                filtered_data = pd.concat([filtered_data,new_row], ignore_index=True).drop_duplicates(subset="ID", keep="last")\n            else: continue\n    entity_id_list[:] = list(set(entity_id_list))# unique related IDs\n\n    # Return results in Pandas DataFrame\n    return filte ...

# %% [markdown]
# ## Execution

# %%
#DataFrame init
df_entities = pd.DataFrame()
df_relationships = pd.DataFrame()

# %%
#get relationships (level 1)
trump_related_ids= set()
df_relationships = add_to_df(df_relationships,get_relationships_LS([15108],trump_related_ids))

# %%
print(df_relationships.shape[0],df_entities.shape[0])
# Out:
# 2799 0

# %%
#get related entities (level 1)
df_entities = add_to_df(df_entities,get_entities_LS(trump_related_ids))

# %%
# get Trump connected level 2 relationships (positions + ownership only)
trump_lvl2_related_ids = set()
df_relationships = add_to_df(df_relationships,get_relationships_LS(trump_related_ids,trump_lvl2_related_ids,rel_categories={1,10,11}))
# Out:
# C:\Users\rober\AppData\Local\Temp\ipykernel_19328\1457603684.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat([source,extension], ignore_index=True).drop_duplicates(subset="ID", keep="last")

# %%
# get level 2 related entities
df_entities = add_to_df(df_entities,get_entities_LS(trump_lvl2_related_ids))

# %%
print(df_relationships.shape[0],df_entities.shape[0])
# Out:
# 13520 10743

# %% [markdown]
# | #  | Name                  | Description |
# |----|-----------------------|-------------|
# | 1  | Position (P+O/P+P only) | When a person has a place in an organizational hierarchy, usually carrying a title. Positions can be paid or unpaid. **Examples:** CEO, Director, Trustee, Chief Counsel, Professor, etc. |
# | 2  | Education (P+O only)   | When a person attends a school or educational program as a student. |
# | 3  | Membership            | When a person is a member of a membership organization but doesn’t hold a position, or when an organization is a member of a larger coalition or association. **Examples:** AFL-CIO, NRA, National Association of Manufacturers, etc. |
# | 4  | Family (P+P only)     | When two people are part of the same family. **Examples:** children, spouses, cousins, siblings, etc. |
# | 5  | Donation/Grant        | A gift transfer of money, goods, or services with nothing due in return. **Examples:** political funding, contributions to charities, government grants, prizes. |
# | 6  | Service/Transaction   | An exchange of money, goods, or services of about equal value. **Examples:** purchases, consulting, contract work, accounting, trades, etc. |
# | 7  | Lobbying              | When an organization directly lobbies a government agency or official. **Examples:** organization that employs lobbyists in-house, lobbying firm hired by an organization. |
# | 8  | Social (P+P only)     | When two people are socially acquainted. **Examples:** friends, rivals, lovers, tennis partners, etc. |
# | 9  | Professional (P+P only) | When two people have a direct working or business relationship. **Examples:** co-writers, business partners, mentors, etc. |
# | 10 | Ownership (O+O/P+O only) | When a person or organization has full or partial ownership of an organization. **Examples:** sole proprietor, limited partners, shareholders, etc. |
# | 11 | Hierarchy (O+O only)  | When an organization is the parent or child of another organization. **Examples:** foundation, lobbying arm, political arm, etc. |
# | 12 | Generic               | A generic type for affiliations that do not fit into any of the regular types of relationships. |

# %% [markdown]
# pro organizace: 11, 10
# pro lidi: 1, 5,6, 7, 9

# %% [markdown]
# ### Export raw

# %%
df_relationships.to_csv('relationships.csv',index=False)
df_entities.to_csv('entities.csv',index=False)

# %% [markdown]
# ## Transformace

# %%
entities = pd.read_csv('entities.csv')
relationships = pd.read_csv('relationships.csv')

# %%
# description concatenation
relationships["Description_1"] = relationships.apply(
    lambda row: "; ".join([val for val in [row["Description_1"], row["Description_2"]] if pd.notna(val)])
    if row["Description_1"] != row["Description_2"] else row["Description_1"],
    axis=1
)

# %%
#pridani sloupce id_all (spojeni obou ID pro snazsi vyhledavani)
relationships["ID_all"] = relationships["Entity1_ID"].astype(str) + ', ' + relationships["Entity2_ID"].astype(str)

# %%
# oprava minusovych hodnot v amount
relationships["amount"] = relationships["amount"].abs()

# %%
entities
# Out:
#            ID                                               Name  \
# 0           1                                       Walmart Inc.
# 1           2                                         ExxonMobil
# 2           3                                            Chevron
# 3           4                             General Motors Company
# 4           5                                     ConocoPhillips
# ...       ...                                                ...
# 10738  455281  PREVENTING INFORMATION REMOVAL AND NABBING HAR...
# 10739  455282  Strategies for Investigating and Eliciting Inf...
# 10740  455317                                        Amy Gleason
# 10741  455346                              Tesla Automation GmbH
# 10742  455353                              Crockett Ventures LLC
#
#                                                  Aliases    Type  \
# 0      IRS EIN 71-0415188;Wal-Mart;Wal-Mart Stores, I...     Org
# 1      Esso;Exxon Corporation;Exxon Mobil;Exxon Mobil...     Org
# 2      Chevron;Chevron Corporation;ChevronTexaco;IRS ...     Org
# 3      GM;General Motors;General Motors Company;Gener...     Org
# 4      Conoco Inc.;ConocoPhillips;ConocoPhillips Hold...     Org
# ...                                                  ...     ...
# 10738  PREVENTING INFORMATION REMOVAL AND NABBING HAR...     Org
# 10739  Strategies for Investigating and Eliciting Inf...     Org
# 10740                                        Amy Gleason  Person
# 10741         Grohmann Engineering;Tesla Automation GmbH     Org
# 10742                              Crockett Ventures LLC     Org
#
#                                   Types_other  \
# 0      Organization; Business; Public Company
# 1      Organization; Business; Public Company
# 2      Organization; Business; Public Company
# 3      Organization; Business; Public Company
# 4      Organization; Business; Public Company
# ...                                       ...
# 10738                            Organization
# 10739                            Organization
# 10740                 Person; Business Person
# 10741                  Organization; Business
# 10742                            Organization
#
#                                              Description  \
# 0                                   Retail merchandising
# 1      Oil and gas exploration, production, and marke...
# 2                                         Energy Company
# 3                                automobile manufacturer
# 4                    Texas-based oil and gas corporation
# ...                                                  ...
# 10738                                                NaN
# 10739                                      DARPA program
# 10740       Nashville tech executive, DOGE administrator
# 10741                            Tesla German subsidiary
# 10742                                Lee Beaman company
#
#                     Updated  \
# 0      2024-07-15T21:29:07Z
# 1      2025-02-21T23:06:40Z
# 2      2025-02-21T23:06:54Z
# 3      2025-02-03T15:40:42Z
# 4      2023-09-02T18:25:19Z
# ...                     ...
# 10738  2025-02-24T17:44:38Z
# 10739  2025-02-25T18:01:27Z
# 10740  2025-02-26T02:43:24Z
# 10741  2025-02-27T22:23:50Z
# 10742  2025-02-28T16:20:29Z
#
#                                                    Links     Source
# 0          https://littlesis.org/entities/1-Walmart_Inc.  Littlesis
# 1            https://littlesis.org/entities/2-ExxonMobil  Littlesis
# 2               https://littlesis.org/entities/3-Chevron  Littlesis
# 3      https://littlesis.org/entities/4-General_Motor...  Littlesis
# 4        https://littlesis.org/entities/5-ConocoPhillips  Littlesis
# ...                                                  ...        ...
# 10738  https://littlesis.org/entities/455281-PREVENTI...  Littlesis
# 10739  https://littlesis.org/entities/455282-Strategi...  Littlesis
# 10740  https://littlesis.org/entities/455317-Amy_Gleason  Littlesis
# 10741  https://littlesis.org/entities/455346-Tesla_Au...  Littlesis
# 10742  https://littlesis.org/entities/455353-Crockett...  Littlesis
#
# [10743 rows x 9 columns]

# %%
relationships
# Out:
#             ID  Entity1_ID  Entity2_ID  Category_ID   Category_desc  \
# 0       232530       50049       15108            9    Professional
# 1       232531       49948       15108            9    Professional
# 2       297889       15108       29581            5  Donation/Grant
# 3       297890       15108       28801            5  Donation/Grant
# 4       297891       15108       13422            5  Donation/Grant
# ...        ...         ...         ...          ...             ...
# 13515  2001527      139907       14664            1        Position
# 13516  2001593      157922       38938            1        Position
# 13517  2001594       49998       38938            1        Position
# 13518  2001651      455536       38804            1        Position
# 13519  2002158       15362      369465           10       Ownership
#
#                                              Description  \
# 0      Tevfik Arif  and  Donald Trump  are/were a bus...
# 1      Felix Sater  and  Donald Trump  are/were a bus...
# 2      Donald Trump  gave money to  Solutions America...
# 3            Donald Trump  gave money to  Rudy Giuliani
# 4         Donald Trump  gave money to  Frank A Lobiondo
# ...                                                  ...
# 13515  Kelly Loeffler  has a position (administrator)...
# 13516  Laura Ingraham  has/had a position (Position) ...
# 13517  Maria Bartiromo  has/had a position (Position)...
# 13518  Riccardo Biasini  has/had a position (software...
# 13519        Mark Zuckerberg  is/was an owner of  Asana
#
#                Description_1          Description_2 is_current is_board  \
# 0       a business associate   a business associate        NaN      NaN
# 1       a business associate   a business associate        NaN      NaN
# 2      Campaign Contribution  Campaign Contribution        NaN      NaN
# 3      Campaign Contribution  Campaign Contribution        NaN      NaN
# 4      Campaign Contribution  Campaign Contribution        NaN      NaN
# ...                      ...                    ...        ...      ...
# 13515          administrator                    NaN       True      NaN
# 13516                                           NaN        NaN      NaN
# 13517                                           NaN        NaN      NaN
# 13518      software engineer                    NaN        NaN      NaN
# 13519                                           NaN        NaN      NaN
#
#       is_executive is_employee  amount currency  Start_date    End_date  \
# 0              NaN         NaN     NaN      NaN         NaN         NaN
# 1              NaN         NaN     NaN      NaN         NaN         NaN
# 2              NaN         NaN  6500.0      usd  1999-00-00  2004-00-00
# 3              NaN         NaN  1000.0      usd  1999-00-00  2007-05-15
# 4              NaN         NaN  8250.0      usd  1996-00-00  2007-00-00
# ...            ...         ...     ...      ...         ...         ...
# 13515         True         NaN     NaN      NaN  2025-02-20         NaN
# 13516          NaN         NaN     NaN      NaN         NaN         NaN
# 13517          NaN         NaN     NaN      NaN         NaN         NaN
# 13518          NaN        True     NaN      NaN         NaN         NaN
# 13519          NaN         NaN     NaN      NaN         NaN         NaN
#
#                     Updated                                         Link  \
# 0      2010-03-08T21:43:35Z   https://littlesis.org/relationships/232530
# 1      2023-11-08T01:57:29Z   https://littlesis.org/relationships/232531
# 2      2011-01-06T21:31:22Z   https://littlesis.org/relationships/297889
# 3      2017-04-24T14:05:26Z   https://littlesis.org/relationships/297890
# 4      2011-01-06T21:33:07Z   https://littlesis.org/relationships/297891
# ...                     ...                                          ...
# 13515  2025-03-07T16:53:27Z  https://littlesis.org/relationships/2001527
# 13516  2025-03-08T02:12:42Z  https://littlesis.org/relationships/2001593
# 13517  2025-03-08T02:13:20Z  https://littlesis.org/relationships/2001594
# 13518  2025-03-09T17:40:42Z  https://littlesis.org/relationships/2001651
# 13519  2025-03-14T08:42:29Z  https://littlesis.org/relationships/2002158
#
#               ID_all
# 0       50049, 15108
# 1       49948, 15108
# 2       15108, 29581
# 3       15108, 28801
# 4       15108, 13422
# ...              ...
# 13515  139907, 14664
# 13516  157922, 38938
# 13517   49998, 38938
# 13518  455536, 38804
# 13519  15362, 369465
#
# [13520 rows x 19 columns]

# %% [markdown]
# ### Export transformed

# %%
relationships.columns = relationships.columns.str.lower()
entities.columns = entities.columns.str.lower()

relationships.to_csv('relationships.csv',index=False)
entities.to_csv('entities.csv',index=False)

# %% [markdown]
# ### SQL Analyza

# %%
duckdb.query("SELECT category_desc, count(*) as count FROM relationships group by all having count(*) >1 order by 2 desc").to_df()
# Out:
#           category_desc  count
# 0              Position   9865
# 1        Donation/Grant   2196
# 2             Ownership    809
# 3             Hierarchy    221
# 4               Generic    140
# 5          Professional    129
# 6   Service/Transaction     69
# 7                Social     63
# 8                Family     22
# 9            Membership      4
# 10            Education      2

# %%
orgs_rels = duckdb.query(
    "SELECT distinct r.* FROM entities e inner JOIN relationships r "
    "   on e.ID = r.entity1_ID or e.ID = r.entity2_ID "
    "WHERE type = 'Org' "
    ).to_df()

orgs_rels
# Out:
#            id  entity1_id  entity2_id  category_id category_desc  \
# 0          48        1045           2            1      Position
# 1       30421       15557           2            1      Position
# 2       30423       15559           2            1      Position
# 3       30445       15567           2            1      Position
# 4       30451       15571           2            1      Position
# ...       ...         ...         ...          ...           ...
# 9464  1989052      268377      402358            1      Position
# 9465  1989870      102193      451894            1      Position
# 9466  1999059      222770      455136           10     Ownership
# 9467  1999981      455281      455251           11     Hierarchy
# 9468  2001104      455436      455251            1      Position
#
#                                             description description_1  \
# 0     Rex Tillerson  had a position (Director) at  E...      Director
# 1     G O Wilhelm  has/had a position (Lobbyist) at ...      Lobbyist
# 2     J O Luby Jr  has/had a position (Lobbyist) at ...      Lobbyist
# 3     J A Cole  has/had a position (Lobbyist) at  Ex...      Lobbyist
# 4     L D Jackson  has/had a position (Lobbyist) at ...      Lobbyist
# ...                                                 ...           ...
# 9464  Chris Krebs  has/had a position (Position) at ...
# 9465  Donald Trump Jr.  has/had a position (Position...
# 9466  Tom Homan  is/was an owner of  Homeland Strate...
# 9467  PREVENTING INFORMATION REMOVAL AND NABBING HAR...
# 9468  Numa Dhamani  has/had a position (Position) at...
#
#      description_2  is_current  is_board  is_executive  is_employee  amount  \
# 0         Director       False      True         False         <NA>     NaN
# 1         Lobbyist        <NA>      <NA>          <NA>         True     NaN
# 2         Lobbyist        <NA>      <NA>          <NA>         True     NaN
# 3         Lobbyist        <NA>      <NA>          <NA>         True     NaN
# 4         Lobbyist        <NA>      <NA>          <NA>         True     NaN
# ...            ...         ...       ...           ...          ...     ...
# 9464          None        <NA>      <NA>          <NA>         <NA>     NaN
# 9465          None        <NA>      <NA>          <NA>         <NA>     NaN
# 9466          None        <NA>      <NA>          <NA>         <NA>     NaN
# 9467          None        <NA>      <NA>          <NA>         <NA>     NaN
# 9468          None        <NA>      <NA>          <NA>         <NA>     NaN
#
#      currency  start_date end_date               updated  \
# 0        None  2004-00-00     None  2018-02-15T02:58:35Z
# 1        None        None     None  2008-11-10T22:45:06Z
# 2        None        None     None  2008-11-10T22:45:06Z
# 3        None        None     None  2008-11-10T22:45:13Z
# 4        None        None     None  2008-11-10T22:45:18Z
# ...       ...         ...      ...                   ...
# 9464     None        None     None  2024-11-18T17:44:53Z
# 9465     None        None     None  2024-11-28T02:51:15Z
# 9466     None        None     None  2025-02-18T17:26:58Z
# 9467     None        None     None  2025-02-24T17:44:38Z
# 9468     None        None     None  2025-03-04T19:17:45Z
#
#                                              link          id_all
# 0          https://littlesis.org/relationships/48         1045, 2
# 1       https://littlesis.org/relationships/30421        15557, 2
# 2       https://littlesis.org/relationships/30423        15559, 2
# 3       https://littlesis.org/relationships/30445        15567, 2
# 4       https://littlesis.org/relationships/30451        15571, 2
# ...                                           ...             ...
# 9464  https://littlesis.org/relationships/1989052  268377, 402358
# 9465  https://littlesis.org/relationships/1989870  102193, 451894
# 9466  https://littlesis.org/relationships/1999059  222770, 455136
# 9467  https://littlesis.org/relationships/1999981  455281, 455251
# 9468  https://littlesis.org/relationships/2001104  455436, 455251
#
# [9469 rows x 19 columns]

# %%
lvl1 = duckdb.query("SELECT* FROM relationships where id_all like '%15108%'").to_df()
pd.DataFrame(lvl1["category_desc"].value_counts())
# Out:
#                      count
# category_desc
# Donation/Grant        2196
# Position               146
# Generic                140
# Professional           129
# Service/Transaction     69
# Social                  63
# Ownership               28
# Family                  22
# Membership               4
# Education                2

# %%
duckdb.query(
    "SELECT  category_id ,category_desc, count(*) FROM orgs_rels group by 1,2 "
).to_df()
# Out:
#    category_id        category_desc  count_star()
# 0            1             Position          8274
# 1           12              Generic            59
# 2           10            Ownership           808
# 3            3           Membership             4
# 4           11            Hierarchy           221
# 5            2            Education             2
# 6            6  Service/Transaction            27
# 7            5       Donation/Grant            74

# %%
duckdb.query(
    "SELECT  category_id, Category_desc, count(*), FROM relationships r left join entities e on e.ID = r.entity1_ID"
    " left join entities e2 on e2.ID = r.entity2_ID "
    "WHERE Entity1_ID = 15108 or entity2_ID = 15108 "
    "group by category_id, Category_desc order by 3 "
).to_df()
# Out:
#    category_id        category_desc  count_star()
# 0            2            Education             2
# 1            3           Membership             4
# 2            4               Family            22
# 3           10            Ownership            28
# 4            8               Social            63
# 5            6  Service/Transaction            69
# 6            9         Professional           129
# 7           12              Generic           140
# 8            1             Position           146
# 9            5       Donation/Grant          2196

# %%
df_rel_l2 = duckdb.query(
    "SELECT * FROM relationships where id_all not like '%15108%' "
).to_df()

# %%
duckdb.query(
    "SELECT * FROM relationships WHERE is_current = 'True' and end_date is not null"
).to_df()
# Out:
#          id  entity1_id  entity2_id  category_id        category_desc  \
# 0   1562917      138555       15108            6  Service/Transaction
# 1       636        1356          27            1             Position
# 2     36134       19016       19015            1             Position
# 3     92853       34615       34616            1             Position
# 4     92856       13450       12885            1             Position
# 5    117104       13762       14640            1             Position
# 6    133310        3289         168            1             Position
# 7    264030       58489           2            1             Position
# 8    264035       58492           2            1             Position
# 9    386325       15067       90705            1             Position
# 10   471028       83350       43886            1             Position
# 11   472481      104169       38804            1             Position
# 12   546779       38805       87699            1             Position
# 13   563912      119420           2            1             Position
# 14   563936       21078           5            1             Position
# 15   563941      119437           5            1             Position
# 16   570918      122860       90705            1             Position
# 17   575671      103239       90629            1             Position
# 18   883740       42978         333            1             Position
# 19   906998      184855       90705            1             Position
# 20   922791      189411           2            1             Position
# 21   999079       91592       36930            1             Position
# 22  1158979        5729      245338            1             Position
# 23  1303373      145285       29025            1             Position
# 24  1345694       49959      226947            1             Position
# 25  1396066      288154       90705            1             Position
# 26  1403594      119436           5            1             Position
# 27  1416691        1798           5            1             Position
# 28  1447088      143500      282983            1             Position
# 29  1453362      124785       38804            1             Position
# 30  1475994      125351       90705            1             Position
# 31  1482120      332557      211566            1             Position
# 32  1546094        1291       14605            1             Position
# 33  1630265      137108          27            1             Position
# 34  1642755      256947      366375            1             Position
# 35  1662807      230807       79865            1             Position
# 36  1726082      325401       14665            1             Position
# 37  1738776       13587      276478            1             Position
# 38  1780351      415130       34264            1             Position
# 39  1784106       41340       28220            1             Position
#
#                                           description  \
# 0          John Dowd  and  Donald Trump  did business
# 1   Edward M Liddy  has a position (Director) at  ...
# 2   H Rodgin Cohen  has a position (Chairman) at  ...
# 3   Wayne LaPierre  has a position (Executive Vice...
# 4   Mitch McConnell  has a position (Minority Lead...
# 5   Tom Daschle  has a position (Secretary - desig...
# 6   David J Lesar  has a position (COO) at  Hallib...
# 7   Jack P Williams Jr  has a position (Senior Vic...
# 8   James M Spellings Jr  has a position (Vice Pre...
# 9   Richard Kinder  has a position (Chairman & Chi...
# 10  Andrew J Littlefair  has a position (Co-founde...
# 11  George Blankenship  has a position (VP - Sales...
# 12  Elon Musk  has a position (Founder, CEO,  & Ch...
# 13  Stephen M Greenlee  has a position (Vice Presi...
# 14  Andrew Lundquist  has a position (Senior Vice ...
# 15  Matthew J Fox  has a position (Executive Vice ...
# 16  Dax Sanders  has a position (Vice President - ...
# 17  Scott Angelle  has a position (Board Member) a...
# 18  J Jeffrey Louis  has a position (Board Member)...
# 19  Kimberly Allen Dang  has a position (Vice Pres...
# 20  Neil A Chapman  has a position (Vice President...
# 21  Kathy Hochul  has a position (Lieutenant Gover...
# 22  Kelcy Warren  has a position (Commissioner) at...
# 23  Leora Levy  has a position (National Committee...
# 24  Alex Azar  has a position (Board Member) at  H...
# 25  Patrick Bourgoyne  has a position (Vice Presid...
# 26  Jody Freeman  has a position (Independent Dire...
# 27  Robert A Niblock  has a position (Chairman (Hu...
# 28  Robert Luddy  has a position (Director) at  Mi...
# 29  Deepak Ahuja  has a position (CFO) at  Tesla, ...
# 30  David Patrick Michels  has a position (Vice Pr...
# 31  Susie Wiles  has a position (Partner and EVP) ...
# 32  William Barr  has a position (Attorney General...
# 33  Greg Smith  has a position (Interim CEO) at  B...
# 34  Andrea Thompson  has a position (Associate Dea...
# 35  Lee Beaman  has a position (Board of Directors...
# 36  Steven Dillingham  has a position (Director) a...
# 37  Richard Shelby  has a position (Senior Senator...
# 38  David Clements  has a position (Assistant Prof...
# 39  Charles Koch  has a position (Chairman (Board ...
#
#                                         description_1  \
# 0                               legal advisor; client
# 1                                            Director
# 2                                            Chairman
# 3                            Executive Vice President
# 4                                     Minority Leader
# 5                               Secretary - designate
# 6                                                 COO
# 7            Senior Vice President; Executive Officer
# 8   Vice President and General Tax Counsel; Vice P...
# 9             Chairman & Chief Executive Officer; CEO
# 10                                         Co-founder
# 11                                         VP - Sales
# 12                    Founder, CEO,  & Chair; Founder
# 13       Vice President and President; Vice President
# 14    Senior Vice President - Government Affairs; SVP
# 15  Executive Vice President ; Executive Vice Pres...
# 16  Vice President - Corporate Development; Vice P...
# 17
# 18
# 19  Vice President and Chief Financial Officer; VP...
# 20                                     Vice President
# 21                    Lieutenant Governor of New York
# 22                                       Commissioner
# 23                            National Committeewoman
# 24
# 25                     Vice President, Internal Audit
# 26                               Independent Director
# 27  Chairman (Human Resources and Compensation Com...
# 28                                           Director
# 29                                                CFO
# 30     Vice President, Finance and Investor Relations
# 31                                    Partner and EVP
# 32                                   Attorney General
# 33                                        Interim CEO
# 34                                     Associate Dean
# 35                                 Board of Directors
# 36                                           Director
# 37                                     Senior Senator
# 38                               Assistant Professor
# 39  Chairman (Board of Directors), Chief Executive...
#
#                       description_2  is_current  is_board  is_executive  \
# 0                            client        True      <NA>          <NA>
# 1                          Director        True      True         False
# 2                          Chairman        True      <NA>          <NA>
# 3          Executive Vice President        True      <NA>          True
# 4                   Minority Leader        True      <NA>          <NA>
# 5             Secretary - designate        True      <NA>          <NA>
# 6                               COO        True      True          True
# 7                 Executive Officer        True     False          True
# 8                    Vice President        True     False          True
# 9                               CEO        True      True          <NA>
# 10                       Co-founder        True      True          <NA>
# 11                       VP - Sales        True      <NA>          True
# 12                          Founder        True      True          True
# 13                   Vice President        True     False          True
# 14                              SVP        True     False          True
# 15         Executive Vice President        True     False          True
# 16                   Vice President        True     False          True
# 17                             None        True      True         False
# 18                             None        True      True          <NA>
# 19                         VP, CFO         True      True          <NA>
# 20                   Vice President        True     False          True
# 21  Lieutenant Governor of New York        True      <NA>          <NA>
# 22                     Commissioner        True      True          <NA>
# 23                             None        True      <NA>          <NA>
# 24                             None        True      True          <NA>
# 25                             None        True     False          True
# 26                             None        True      True          <NA>
# 27                             None        True      True          <NA>
# 28                             None        True      True          <NA>
# 29                              CFO        True      <NA>          <NA>
# 30                             None        True     False          True
# 31                             None        True      <NA>          <NA>
# 32                             None        True      <NA>          <NA>
# 33                             None        True      <NA>          <NA>
# 34                             None        True     False         False
# 35                             None        True      True          <NA>
# 36                             None        True      <NA>          <NA>
# 37                             None        True      <NA>          <NA>
# 38                             None        True      <NA>          <NA>
# 39                             None        True      <NA>          <NA>
#
#     is_employee  amount currency  start_date    end_date  \
# 0          <NA>     NaN     None  2017-06-00  2018-03-00
# 1         False     NaN     None  2007-00-00  2008-10-27
# 2         False     NaN     None  2000-00-00  2009-00-00
# 3          <NA>     NaN     None        None  2024-01-31
# 4          <NA>     NaN     None  2007-00-00  2024-11-00
# 5          <NA>     NaN     None  2008-11-00  2009-02-03
# 6          True     NaN     None  1997-00-00  2000-00-00
# 7          <NA>     NaN     None        None  2015-00-00
# 8          <NA>     NaN     None        None  2015-00-00
# 9          <NA>     NaN     None        None  2015-00-00
# 10         <NA>     NaN     None  1997-00-00  1997-00-00
# 11         <NA>     NaN     None  2010-07-00  2013-11-00
# 12         True     NaN     None  2002-06-00  2002-06-00
# 13         <NA>     NaN     None        None  2015-00-00
# 14         <NA>     NaN     None        None  2015-00-00
# 15         <NA>     NaN     None        None  2015-00-00
# 16         <NA>     NaN     None        None  2015-00-00
# 17         <NA>     NaN     None  2012-12-00  2017-05-00
# 18         <NA>     NaN     None  1985-00-00  1995-00-00
# 19         <NA>     NaN     None        None  2015-00-00
# 20         <NA>     NaN     None        None  2015-00-00
# 21         <NA>     NaN     None  2015-01-01  2021-08-24
# 22         <NA>     NaN     None  2015-00-00  2021-00-00
# 23         <NA>     NaN     None  2016-00-00  2020-00-00
# 24         <NA>     NaN     None        None  2016-10-00
# 25         <NA>     NaN     None        None  2015-00-00
# 26         <NA>     NaN     None        None  2015-00-00
# 27         <NA>     NaN     None        None  2015-00-00
# 28         <NA>     NaN     None        None  2015-00-00
# 29         <NA>     NaN     None        None  2015-00-00
# 30         <NA>     NaN     None        None  2015-00-00
# 31         <NA>     NaN     None  2011-00-00  2019-00-00
# 32         <NA>     NaN     None  2019-02-14  2020-12-23
# 33         <NA>     NaN     None  2019-12-00  2020-01-19
# 34         True     NaN     None  2020-01-07  2020-06-21
# 35         <NA>     NaN     None        None  2018-00-00
# 36         <NA>     NaN     None        None  2021-01-20
# 37         <NA>     NaN     None  1987-01-06  2023-01-03
# 38         <NA>     NaN     None        None  2018-08-00
# 39         <NA>     NaN     None        None  2015-00-00
#
#                  updated                                         link  \
# 0   2019-06-23T15:02:41Z  https://littlesis.org/relationships/1562917
# 1   2015-03-31T15:34:53Z      https://littlesis.org/relationships/636
# 2   2011-02-21T14:05:40Z    https://littlesis.org/relationships/36134
# 3   2024-01-30T01:44:32Z    https://littlesis.org/relationships/92853
# 4   2024-10-25T02:46:39Z    https://littlesis.org/relationships/92856
# 5   2009-02-04T09:17:23Z   https://littlesis.org/relationships/117104
# 6   2015-03-31T17:52:36Z   https://littlesis.org/relationships/133310
# 7   2020-09-16T19:25:20Z   https://littlesis.org/relationships/264030
# 8   2020-09-16T19:25:20Z   https://littlesis.org/relationships/264035
# 9   2020-09-16T19:13:15Z   https://littlesis.org/relationships/386325
# 10  2015-04-01T15:45:36Z   https://littlesis.org/relationships/471028
# 11  2016-05-19T14:20:45Z   https://littlesis.org/relationships/472481
# 12  2024-10-19T22:06:02Z   https://littlesis.org/relationships/546779
# 13  2020-09-16T19:25:19Z   https://littlesis.org/relationships/563912
# 14  2020-09-16T19:26:30Z   https://littlesis.org/relationships/563936
# 15  2020-09-16T19:26:30Z   https://littlesis.org/relationships/563941
# 16  2020-09-16T19:13:16Z   https://littlesis.org/relationships/570918
# 17  2018-11-12T23:05:44Z   https://littlesis.org/relationships/575671
# 18  2016-05-13T14:05:23Z   https://littlesis.org/relationships/883740
# 19  2020-09-16T19:13:14Z   https://littlesis.org/relationships/906998
# 20  2020-09-16T19:25:18Z   https://littlesis.org/relationships/922791
# 21  2021-08-10T17:01:54Z   https://littlesis.org/relationships/999079
# 22  2021-02-26T01:24:17Z  https://littlesis.org/relationships/1158979
# 23  2017-06-01T08:04:05Z  https://littlesis.org/relationships/1303373
# 24  2017-11-13T18:24:35Z  https://littlesis.org/relationships/1345694
# 25  2020-09-16T19:13:14Z  https://littlesis.org/relationships/1396066
# 26  2020-09-16T19:26:30Z  https://littlesis.org/relationships/1403594
# 27  2020-09-16T19:26:30Z  https://littlesis.org/relationships/1416691
# 28  2020-09-16T18:40:56Z  https://littlesis.org/relationships/1447088
# 29  2018-06-27T13:13:22Z  https://littlesis.org/relationships/1453362
# 30  2020-09-16T19:13:16Z  https://littlesis.org/relationships/1475994
# 31  2024-11-16T05:59:35Z  https://littlesis.org/relationships/1482120
# 32  2020-12-14T23:20:57Z  https://littlesis.org/relationships/1546094
# 33  2019-12-29T06:22:54Z  https://littlesis.org/relationships/1630265
# 34  2020-02-06T08:50:51Z  https://littlesis.org/relationships/1642755
# 35  2020-04-15T18:30:30Z  https://littlesis.org/relationships/1662807
# 36  2021-01-18T22:59:42Z  https://littlesis.org/relationships/1726082
# 37  2020-11-24T06:26:32Z  https://littlesis.org/relationships/1738776
# 38  2024-08-19T02:31:22Z  https://littlesis.org/relationships/1780351
# 39  2023-10-24T18:19:55Z  https://littlesis.org/relationships/1784106
#
#             id_all
# 0    138555, 15108
# 1         1356, 27
# 2     19016, 19015
# 3     34615, 34616
# 4     13450, 12885
# 5     13762, 14640
# 6        3289, 168
# 7         58489, 2
# 8         58492, 2
# 9     15067, 90705
# 10    83350, 43886
# 11   104169, 38804
# 12    38805, 87699
# 13       119420, 2
# 14        21078, 5
# 15       119437, 5
# 16   122860, 90705
# 17   103239, 90629
# 18      42978, 333
# 19   184855, 90705
# 20       189411, 2
# 21    91592, 36930
# 22    5729, 245338
# 23   145285, 29025
# 24   49959, 226947
# 25   288154, 90705
# 26       119436, 5
# 27         1798, 5
# 28  143500, 282983
# 29   124785, 38804
# 30   125351, 90705
# 31  332557, 211566
# 32     1291, 14605
# 33      137108, 27
# 34  256947, 366375
# 35   230807, 79865
# 36   325401, 14665
# 37   13587, 276478
# 38   415130, 34264
# 39    41340, 28220

# %%
# is current + is board 
q= "SELECT distinct e.* FROM entities e LEFT JOIN relationships r on e.ID = r.entity1_ID or e.ID = r.entity2_ID where category_id = 5 "
duckdb.query(q).to_df()
# Out:
#           id                                               name  \
# 0      28670  Democratic Congressional Campaign Committee - ...
# 1      29038                        Searchlight Leadership Fund
# 2      13271                                        John Ensign
# 3      13935                                         Al D’Amato
# 4      13541                                         Harry Reid
# ...      ...                                                ...
# 2176  451123                                    Cornelia Matson
# 2177  451583                                       Laura Ramsey
# 2178  454577                                       John D Giles
# 2179  454798                                    Kevin Delbridge
# 2180  455099                                       Emil Bove Jr
#
#                                                 aliases    type  \
# 0     C00347864;DCCC;Democratic Congressional Campai...     Org
# 1                           Searchlight Leadership Fund     Org
# 2                          John Ensign;John Eric Ensign  Person
# 3     Al D’Amato;Alfonse D'Amato;Alfonse Damato;Alfo...  Person
# 4                                 Harry Reid;Harry Reid  Person
# ...                                                 ...     ...
# 2176               Cornelia Long Matson;Cornelia Matson  Person
# 2177                                       Laura Ramsey  Person
# 2178                                       John D Giles  Person
# 2179                                    Kevin Delbridge  Person
# 2180                                       Emil Bove Jr  Person
#
#                                             types_other  \
# 0     Organization; Political Fundraising Committee;...
# 1     Organization; Political Fundraising Committee;...
# 2     Person; Political Candidate; Elected Represent...
# 3     Person; Political Candidate; Elected Represent...
# 4     Person; Political Candidate; Elected Represent...
# ...                                                 ...
# 2176                                             Person
# 2177                                             Person
# 2178                            Person; Business Person
# 2179                                             Person
# 2180                                     Person; Lawyer
#
#                                             description               updated  \
# 0                                                  None  2025-01-23T15:20:39Z
# 1                         Affiliate: Harry Reid (D-Nev)  2020-05-04T17:33:37Z
# 2      former US Senator and Representative from Nevada  2024-11-21T17:49:54Z
# 3             US Senator from New York; Park Strategies  2021-03-17T20:28:22Z
# 4        Late US Senator and Representative from Nevada  2025-01-23T20:47:52Z
# ...                                                 ...                   ...
# 2176                                  Sarasota Florida   2024-10-29T22:01:43Z
# 2177                              Retired, Shiloh Ohio   2024-11-21T18:07:40Z
# 2178    Butler Business Systems - Butler, Pennsylvania   2025-01-07T16:56:50Z
# 2179                           Retired. Naples Florida   2025-01-20T20:02:35Z
# 2180  Retired attorney,  Seneca Falls NY based law f...  2025-02-14T20:59:50Z
#
#                                                   links     source
# 0     https://littlesis.org/entities/28670-Democrati...  Littlesis
# 1     https://littlesis.org/entities/29038-Searchlig...  Littlesis
# 2      https://littlesis.org/entities/13271-John_Ensign  Littlesis
# 3     https://littlesis.org/entities/13935-Al_D%E2%8...  Littlesis
# 4       https://littlesis.org/entities/13541-Harry_Reid  Littlesis
# ...                                                 ...        ...
# 2176  https://littlesis.org/entities/451123-Cornelia...  Littlesis
# 2177  https://littlesis.org/entities/451583-Laura_Ra...  Littlesis
# 2178  https://littlesis.org/entities/454577-John_D_G...  Littlesis
# 2179  https://littlesis.org/entities/454798-Kevin_De...  Littlesis
# 2180  https://littlesis.org/entities/455099-Emil_Bov...  Littlesis
#
# [2181 rows x 9 columns]

# %%
q= "SELECT * FROM relationships where category_id in (11,7)"
duckdb.query(q).to_df()
# Out:
#           id  entity1_id  entity2_id  category_id category_desc  \
# 0     872676         437           2           11     Hierarchy
# 1     872677       87132           2           11     Hierarchy
# 2     872678      103066           2           11     Hierarchy
# 3     872679      108125           2           11     Hierarchy
# 4     872680      111585           2           11     Hierarchy
# ..       ...         ...         ...          ...           ...
# 216  1999640      455251      143943           11     Hierarchy
# 217  1999654      455251       14711           11     Hierarchy
# 218  1999981      455281      455251           11     Hierarchy
# 219  1999984      455282      455251           11     Hierarchy
# 220  2001192      260203      436742           11     Hierarchy
#
#                                            description description_1  \
# 0    XTO Energy Inc.  and  ExxonMobil  have a hiera...
# 1    ExxonMobil Canada Ltd.  and  ExxonMobil  have ...
# 2    Mobil International  and  ExxonMobil  have a h...
# 3    Creole Petroleum Corporation  and  ExxonMobil ...
# 4    ExxonMobil Petroleum & Chemical, BVBA  and  Ex...
# ..                                                 ...           ...
# 216  Active Social Engineering Defense (ASED)  and ...
# 217  Active Social Engineering Defense (ASED)  and ...
# 218  PREVENTING INFORMATION REMOVAL AND NABBING HAR...
# 219  Strategies for Investigating and Eliciting Inf...
# 220  KGB  and  Intourist  had a hierarchical relati...
#
#     description_2  is_current  is_board  is_executive  is_employee  amount  \
# 0            None        True      <NA>          <NA>         <NA>     NaN
# 1            None        True      <NA>          <NA>         <NA>     NaN
# 2            None        True      <NA>          <NA>         <NA>     NaN
# 3            None        True      <NA>          <NA>         <NA>     NaN
# 4            None        True      <NA>          <NA>         <NA>     NaN
# ..            ...         ...       ...           ...          ...     ...
# 216          None        <NA>      <NA>          <NA>         <NA>     NaN
# 217          None        <NA>      <NA>          <NA>         <NA>     NaN
# 218          None        <NA>      <NA>          <NA>         <NA>     NaN
# 219          None        <NA>      <NA>          <NA>         <NA>     NaN
# 220          None       False      <NA>          <NA>         <NA>     NaN
#
#     currency start_date end_date               updated  \
# 0       None       None     None  2014-12-19T00:20:47Z
# 1       None       None     None  2014-12-19T00:20:47Z
# 2       None       None     None  2014-12-19T00:20:47Z
# 3       None       None     None  2014-12-19T00:20:47Z
# 4       None       None     None  2014-12-19T00:20:47Z
# ..       ...        ...      ...                   ...
# 216     None       None     None  2025-02-24T03:27:00Z
# 217     None       None     None  2025-02-24T07:41:43Z
# 218     None       None     None  2025-02-24T17:44:38Z
# 219     None       None     None  2025-02-24T17:57:11Z
# 220     None       None     None  2025-03-04T23:16:47Z
#
#                                             link          id_all
# 0     https://littlesis.org/relationships/872676          437, 2
# 1     https://littlesis.org/relationships/872677        87132, 2
# 2     https://littlesis.org/relationships/872678       103066, 2
# 3     https://littlesis.org/relationships/872679       108125, 2
# 4     https://littlesis.org/relationships/872680       111585, 2
# ..                                           ...             ...
# 216  https://littlesis.org/relationships/1999640  455251, 143943
# 217  https://littlesis.org/relationships/1999654   455251, 14711
# 218  https://littlesis.org/relationships/1999981  455281, 455251
# 219  https://littlesis.org/relationships/1999984  455282, 455251
# 220  https://littlesis.org/relationships/2001192  260203, 436742
#
# [221 rows x 19 columns]

# %%
duckdb.query("SELECT * FROM entities where lower(name) like 'wayne%'")
duckdb.query("SELECT * FROM relationships where id_all like '%138528%'")
# Out:
# ┌─────────┬────────────┬────────────┬─────────────┬────────────────┬─────────────────────────────────────────────────────────────────────────────────────┬───────────────────────┬───────────────┬────────────┬──────────┬──────────────┬─────────────┬─────────┬──────────┬────────────┬────────────┬──────────────────────┬─────────────────────────────────────────────┬───────────────┐
# │   id    │ entity1_id │ entity2_id │ category_id │ category_desc  │                                     description                                     │     description_1     │ description_2 │ is_current │ is_board │ is_executive │ is_employee │ amount  │ currency │ start_date │  end_date  │       updated        │                    link                     │    id_all     │
# │  int64  │   int64    │   int64    │    int64    │    varchar     │                                       varchar                                       │        varchar        │    varchar    │  boolean   │ boolean  │   boolean    │   boolean   │ double  │ varchar  │  varchar   │  varchar   │       varchar        │                   varchar                   │    varchar    │
# ├─────────┼────────────┼────────────┼─────────────┼────────────────┼─────────────────────────────────────────────────────────────────────────────────────┼───────────────────────┼───────────────┼────────────┼──────────┼──────────────┼─────────────┼─────────┼──────────┼────────────┼────────────┼──────────────────────┼─────────────────────────────────────────────┼───────────────┤
# │ 1841334 │     138528 │      15108 │           5 │ Donation/Grant │ Wayne M Perry  gave money to  Donald Trump                                          │ Campaign Contribution │ NULL          │ false      │ NULL     │ NULL         │ NULL        │ 22400.0 │ usd      │ 2020-10-15 │ 2020-10-16 │ 2022-05-10T15:54:35Z │ https://littlesis.org/relationships/1841334 │ 138528, 15108 │
# │  733241 │     138528 │      38350 │           1 │ Position       │ Wayne M Perry  has a position (Life Trustee) at  New York University School of Law  │ Life Trustee          │ Life Trustee  │ true       │ true     │ NULL         │ NULL        │    NULL │ NULL     │ NULL       │ NULL       │ 2013-12-10T16:17:03Z │ https://littlesis.org/relationships/733241  │ 138528, 38350 │
# └─────────┴────────────┴────────────┴─────────────┴────────────────┴─────────────────────────────────────────────────────────────────────────────────────┴───────────────────────┴───────────────┴────────────┴──────────┴──────────────┴─────────────┴─────────┴──────────┴────────────┴────────────┴──────────────────────┴─────────────────────────────────────────────┴───────────────┘

# %% [markdown]
# # Lobbyview

# %% [markdown]
# ## Import

# %%
lv_reports = pd.read_csv("reports.csv")
lv_clients = pd.read_csv("clients.csv")
lv_issue_text = pd.read_csv("issue_text.csv")
#lv_bills = pd.read_csv("bills.csv")
#lv_issues = pd.read_csv("issues.csv")

# %%
lv_reports.shape
# Out:
# (1690362, 11)

# %%
# odflitrovaní reportů pouze od roku 2016
lv_reports = lv_reports.loc[(lv_reports["filing_year"]) >=2016 ]

# %%
lv_clients
# Out:
#                                      lob_id    gvkey        bvdid     naics  \
# 0      000065ee-5384-579e-b167-c3f782cd0d55      NaN          NaN       NaN
# 1      00031e5d-fb07-526f-be41-0b627892e042      NaN          NaN       NaN
# 2      00046722-0148-5d5d-b6a1-770fdf604147      NaN          NaN       NaN
# 3      0005ff7f-6811-532a-bca3-95557fba29a8      NaN          NaN       NaN
# 4      0007264e-791e-5727-97dd-4c88f2ad9807      NaN          NaN       NaN
# ...                                     ...      ...          ...       ...
# 48522  fffaa78b-38d2-5aff-beb5-bbf6d2b6c7fc  24861.0  US383942097  713940.0
# 48523  fffcf360-06b2-5a06-9eb3-396ff72ac2e4      NaN          NaN       NaN
# 48524  fffe34ed-3548-5caf-a4a8-84598b056728      NaN          NaN       NaN
# 48525  fffe422c-98c0-5bcb-a892-6784c3754a8a      NaN          NaN       NaN
# 48526  ffff3eb4-9082-51ca-b891-9dee20628264      NaN          NaN       NaN
#
#                                              client_name
# 0                                                KALYPSO
# 1                                               PIGEONLY
# 2                          CITY OF OCEAN CITY NEW JERSEY
# 3                           SHELTERS INTERNATIONAL, LLC.
# 4                POLICY INSTITUTE FOR RELIGION AND STATE
# ...                                                  ...
# 48522                               PLANET FITNESS, INC.
# 48523                                      AVI BERNSTEIN
# 48524                            TULSA AIRPORT AUTHORITY
# 48525  360 QUALITY OF LIFE SOLUTIONS (A TRADE ASSOCIA...
# 48526  CIVITAS NETWORKS FOR HEALTH ASSOCIATION (FORME...
#
# [48527 rows x 5 columns]

# %%
lv_reports
# Out:
#                                   report_uuid  \
# 5        15a9cb9e-a0fa-49fe-8c49-c548e9e72903
# 8        4ebd73ee-83d4-404d-9efc-a948ff3c1ffb
# 9        55a4f081-c02e-4312-bcfe-9b6fba434679
# 10       577a9861-7dde-4e95-9f60-4439d4853c3d
# 11       39758514-5b22-4e58-bc58-4c87840209ac
# ...                                       ...
# 1690303  dcf78bf7-f9b5-4845-a3d3-844e0a30ccf8
# 1690304  7658d509-9815-45e8-823e-a6e69f7ab5b9
# 1690305  4a146d53-ff80-49a1-bcfe-223495c4fc03
# 1690306  84a6e67d-4160-4c3a-b49f-3e0ac948756b
# 1690351  a6bd4cb8-a124-40dc-a8c5-41fd9387cb73
#
#                                        lob_id  registrant_id  \
# 5        e9aecce5-0a61-50ad-a2fa-19777ff38542            157
# 8        e9aecce5-0a61-50ad-a2fa-19777ff38542            157
# 9        e9aecce5-0a61-50ad-a2fa-19777ff38542            157
# 10       e9aecce5-0a61-50ad-a2fa-19777ff38542            157
# 11       e9aecce5-0a61-50ad-a2fa-19777ff38542            157
# ...                                       ...            ...
# 1690303  2e6bf10b-802f-56ec-983f-b417d350ad84            157
# 1690304  2e6bf10b-802f-56ec-983f-b417d350ad84            157
# 1690305  2e6bf10b-802f-56ec-983f-b417d350ad84            157
# 1690306  2e6bf10b-802f-56ec-983f-b417d350ad84            157
# 1690351  4a7d2f59-d81d-5363-be24-1535514e7b3c            157
#
#               registrant_name  filing_year filing_period_code   amount  \
# 5        ADAMS AND REESE, LLP         2022                 Q3  20000.0
# 8        ADAMS AND REESE, LLP         2016                 Q1  32000.0
# 9        ADAMS AND REESE, LLP         2016                 Q4  32000.0
# 10       ADAMS AND REESE, LLP         2016                 Q2  32000.0
# 11       ADAMS AND REESE, LLP         2016                 Q3  32000.0
# ...                       ...          ...                ...      ...
# 1690303  ADAMS AND REESE, LLP         2021                 Q1  10000.0
# 1690304  ADAMS AND REESE, LLP         2023                 Q1  10000.0
# 1690305  ADAMS AND REESE, LLP         2023                 Q2  10000.0
# 1690306  ADAMS AND REESE, LLP         2023                 Q3  10000.0
# 1690351  ADAMS AND REESE, LLP         2017                 Q3      NaN
#
#          is_no_activity is_self_filer  is_amendment  \
# 5                 False           NaN         False
# 8                 False           NaN         False
# 9                 False           NaN         False
# 10                False           NaN         False
# 11                False           NaN         False
# ...                 ...           ...           ...
# 1690303           False           NaN         False
# 1690304           False           NaN         False
# 1690305           False           NaN         False
# 1690306           False           NaN         False
# 1690351            True         False         False
#
#                                                 filing_url
# 5        https://lda.senate.gov/filings/public/filing/1...
# 8        https://lda.senate.gov/filings/public/filing/4...
# 9        https://lda.senate.gov/filings/public/filing/5...
# 10       https://lda.senate.gov/filings/public/filing/5...
# 11       https://lda.senate.gov/filings/public/filing/3...
# ...                                                    ...
# 1690303  https://lda.senate.gov/filings/public/filing/d...
# 1690304  https://lda.senate.gov/filings/public/filing/7...
# 1690305  https://lda.senate.gov/filings/public/filing/4...
# 1690306  https://lda.senate.gov/filings/public/filing/8...
# 1690351  https://lda.senate.gov/filings/public/filing/a...
#
# [669798 rows x 11 columns]

# %%
lv_issue_text
# Out:
#                                   report_uuid general_issue_code  \
# 0        000018d7-73cf-403c-bafb-e423afd81c67                MAN
# 1        000018d7-73cf-403c-bafb-e423afd81c67                SCI
# 2        000028d3-9c4e-4a4e-9a76-c1d43456c024                FUE
# 3        000028d3-9c4e-4a4e-9a76-c1d43456c024                ENG
# 4        000028d3-9c4e-4a4e-9a76-c1d43456c024                DEF
# ...                                       ...                ...
# 3161602  ffffe8ae-6894-4cb8-854f-9599aecd6dfb                TAX
# 3161603  ffffe8ae-6894-4cb8-854f-9599aecd6dfb                LBR
# 3161604  ffffe8ae-6894-4cb8-854f-9599aecd6dfb                RET
# 3161605  ffffe8ae-6894-4cb8-854f-9599aecd6dfb                FIN
# 3161606  fffff7b8-f063-4a4d-b498-9df158627496                BUD
#
#          issue_ordinal_position    bill_id_agg  \
# 0                             0            NaN
# 1                             0            NaN
# 2                             0            NaN
# 3                             0            NaN
# 4                             0            NaN
# ...                         ...            ...
# 3161602                       1            NaN
# 3161603                       2            NaN
# 3161604                       3            NaN
# 3161605                       4  {hjres66-115}
# 3161606                       1            NaN
#
#                                                 issue_text
# 0        Issues related to the CHIPS for America Act an...
# 1        Issues related to technological innovations in...
# 2        Issues related to biofuels legislation and reg...
# 3        Issues related to biofuels legislation and reg...
# 4        Issues related to biofuels legislation and reg...
# ...                                                    ...
# 3161602                 Tax reform legislation, generally.
# 3161603                        Issues related to antitrust
# 3161604    Legislation to enhance retirement plan options.
# 3161605  Issues related to the regulation of asset mana...
# 3161606                                     Appropriations
#
# [3161607 rows x 5 columns]

# %% [markdown]
# ## Matching

# %%
def clean_string(name):
    tokens = name.lower().replace(",", "").replace(".", "").replace("&", "and").split()
    return " ".join(t for t in tokens if t not in COMMON_WORDS)

def has_token_overlap(a, b, min_overlap=2):
    tokens_a = set(clean_string(a).split())
    tokens_b = set(clean_string(b).split())
    return len(tokens_a & tokens_b) >= min_overlap or len(tokens_a) == 1 #returns how many tokens the two names have in common, except when length 1

def safe_match(name, cleaned_dict, tsr_threshold=75, ratio_threshold = 0 , min_overlap=2):
    cleaned_input = clean_string(name)

    # Perform fuzzy matching against cleaned values
    result = process.extractOne(cleaned_input, cleaned_dict, scorer=fuzz.token_sort_ratio)

    if result:
        matched_cleaned_value , tsr_score, (match_id, match_name) = result
        ratio_score = fuzz.ratio(name.lower(), match_name.lower())

        if tsr_score >= tsr_threshold and has_token_overlap(name, match_name, min_overlap)  and ratio_score >= ratio_threshold:
            if isinstance(match_id,float): 
                print(match_id)
            return match_id, match_name, tsr_score, ratio_score

    return None, None, None, None

# %%
# common words to exclude/clean 
COMMON_WORDS = {
    "inc", "llc", "ltd", "company", "group", "partners",
    "corp", "corporation", "co", "the", "and", "&", "lp"
}

# %% [markdown]
# ### Fuzzy matching by registrant

# %%
distinct_entity = duckdb.query("SELECT distinct id, name FROM entities where Type='Org' ").to_df()

# %%
distinct_registrant = duckdb.query("SELECT distinct registrant_id, registrant_name FROM lv_reports").to_df()
# dictionary 
lv_entity_cleaned = {
    (row["registrant_id"], row["registrant_name"]): clean_string(row["registrant_name"])
    for _, row in distinct_registrant.iterrows()
}

# %%
fuzzy_matching = distinct_entity
fuzzy_matching[["registrant_id","match","tsr_score","ratio_score"]] = fuzzy_matching["name"].apply(lambda x: pd.Series(safe_match(x,lv_entity_cleaned)) )

# %%
# omezit na vysledky s tsr_score >= 80% 
fuzzy_matching_filtered = duckdb.query("SELECT * FROM fuzzy_matching where match is not null and tsr_score >=80 order by tsr_score, ratio_score").to_df()

# %%
# convert registrant_id back to int64
null_count = int(fuzzy_matching_filtered["registrant_id"].isnull().sum())

if null_count == 0:
    fuzzy_matching_filtered["registrant_id"] = fuzzy_matching_filtered[["registrant_id"]].astype("Int64")
    print("Registrant_id OK")
else: raise ValueError("Registrant_id contains float")
# Out:
# Registrant_id OK

# %% [markdown]
# ### Fuzzy matching by client

# %%
distinct_client = duckdb.query("SELECT  distinct lob_id, client_name FROM lv_clients ").to_df()

# %%
lv_client_cleaned = {
    (row["lob_id"], row["client_name"]): clean_string(row["client_name"])
    for _, row in distinct_client.iterrows()
}

fuzzy_matching_client = distinct_entity
fuzzy_matching_client[["lob_id","match","tsr_score","ratio_score"]] = fuzzy_matching_client["name"].apply(lambda x: pd.Series(safe_match(x,lv_client_cleaned,tsr_threshold=90)) )

# %%
lv_client_cleaned
# Out:
# {('00094d9a-15d6-540e-9c41-15f94e63e1a2',
#   'SRI LANKA APPAREL EXPORTERS ASSN'): 'sri lanka apparel exporters assn',
#  ('0009b134-7190-564a-b9fe-b81bf72c53c4',
#   'AIR SECURITY INTL'): 'air security intl',
#  ('00248509-dfce-55e1-8059-c886bb15de9f', 'INFOCYTE, INC.'): 'infocyte',
#  ('002bb9f2-63df-597c-bc66-4648f8675670',
#   'FORT BELKNAP INDIAN COMMUNITY AND ISLAND MOUNTAIN DEVELOPMENT GROUP'): 'fort belknap indian community island mountain development',
#  ('0033ca9a-b43c-5114-8bea-a49dfe3b6cf7',
#   'FABIANI & COMPANY ON BEHALF OF NATIONAL CHILDHOOD CANCER FOUNDATION'): 'fabiani on behalf of national childhood cancer foundation',
#  ('003ff020-c890-52e5-90d9-749e40d3af0c',
#   'GRAYS HARBOR PAPER'): 'grays harbor paper',
#  ('0043cba3-4bcb-504d-8851-3605a2fc2b03', 'US CELLULAR'): 'us cellular',
#  ('00556832-9de8-50f7-8bd1-3c7978e19338',
#   'GULF STREAM DEVELOPMENT GROUP'): 'gulf stream development',
#  ('00561c67-7970-56bf-a481-e3391f14f133', 'RADIATE GROUP'): 'radiate',
#  ('0057ef85-4494-56ac-a94f-8175b214c241', 'VALUEOPTIONS'): 'valueoptions',
#  ('00610c50-ad63-560a-9c3b-6299e5a5f3e7',
#   'ENTERTAINMENT STUDIOS NETWORKS INC'): 'entertainment studios networks',
#  ('00621aae-fe3c-58df-ac93-fbaf00339cec',
#   'TURNER ENTERPRISES, INC.'): 'turner enterprises',
#  ('0072bec4-984a-57a0-86bc-3b0d5e43f765', 'FLUXERGY, LLC'): 'fluxergy',
#  ('00760187-ccda-5615-8f26-be04ff1c9b50', 'VIATEL INC'): 'viatel',
#  ('007b0b95-4d26-5258-a760-0b5993875cb8',
#   'HOLLY POULTRY INC.'): 'holly poultry',
#  ('00826c01-f9a0-5e9d-aab7-0a0b757608dd',
#   'YORK COLLEGE OF PENNSYLVANIA'): 'york college of pennsylvania',
#  ('00a4cace-30ac-5d88-95d2-d06232a7ca05',
#   'GARDEN STATE CANCER CENTER'): 'garden state cancer center',
#  ('00a5b51b-4bd3-5b3e-b83e-9e8cd6e2fa72',
#   'THE LATINO COALITION'): 'latino coalition',
#  ('00ad2d4d-4670-5686-b65f-1d0eb26258fd',
#   'NATL BURGLAR & FIRE ALARM ASSN'): 'natl burglar fire alarm assn',
#  ('00b19248-cc23-5e38-baf5-c547f5726549', 'LIFEMARK CORP'): 'lifemark',
#  ('00d09186-8532-5680-9766-b15d933adf2f',
#   'VULCAN MATERIALS COMPANY'): 'vulcan materials',
#  ('00db34dd-46f0-5cf8-ac90-4e20f41de857',
#   'CARILION CLINIC'): 'carilion clinic',
#  ('00e7b2f7-76de-544b-88a8-24266181a6cf', 'DUECO INC'): 'dueco',
#  ('00f12d6d-8547-577d-aef3-abfc9fd0f94c', 'VISITALKCOM'): 'visitalkcom',
#  ('00fa5747-6b17-5c04-8615-3a96c35b8324',
#   'AMERICAN ASSN OF PHYSICIANS OF INDIAN ORIGIN'): 'american assn of physicians of indian origin',
#  ('00fbcc97-8b79-5b98-b692-df67f0478069',
#   'LAC VIEUX DESERT BAND OF LAKE SUPERIOR CHIPPEWA'): 'lac vieux desert band of lake superior chippewa',
#  ('0107bc85-4954-55e2-ba31-b6650f7e26aa',
#   'NETEASE INFORMATION TECHNOLOGY CORPORATION'): 'netease information technology',
#  ('011111a1-0eac-537d-b230-59c56b4cc46d',
#   'OFFSHORE RIG MUSEUM INC'): 'offshore rig museum',
#  ('0113189f-0a5f-51c7-ba29-26cf9b5beb38',
#   'SOUND & SEA TECHNOLOGY'): 'sound sea technology',
#  ('011c7383-6b8d-5c6a-8963-70998acd888e', 'RUSS REID COMPANY'): 'russ reid',
#  ('0124bdc5-b52e-5495-ac35-57bb114909e3',
#   'CBI ACQUISITIONS'): 'cbi acquisitions',
#  ('013834dc-aac4-526e-9858-93382a53332c',
#   'ARDMORE ASSOCIATES LLC'): 'ardmore associates',
#  ('013f9d43-b03a-5cd9-b3c7-870ce59273c0', 'SUPERGEN'): 'supergen',
#  ('0144cf7c-60a3-500d-a7dc-d24729ccefab', 'EURAPAIR INTL'): 'eurapair intl',
#  ('015e2e86-3302-556c-9f33-c3f78f792aa4', 'LAHEY CLINIC'): 'lahey clinic',
#  ('01733145-ccc4-56d7-a2c6-ea3489d599a7',
#   'SUB-ONE TECHNOLOGY, INC.'): 'sub-one technology',
#  ('017914cc-a0c6-50e6-b14f-47f8b2668093',
#   'SOUTHWEST MEAT ASSOCIATION'): 'southwest meat association',
#  ('0179ed13-668b-5bbd-9df4-acfd7297dfdc',
#   'REUSABLE PACKAGING ASSOCIATION'): 'reusable packaging association',
#  ('017aa626-369c-57d9-9709-7fc361a0665f', 'ELTA N.A.'): 'elta na',
#  ('0185fba7-ee48-516b-953a-6a89688238ad',
#   'STAINLESS STEEL TUBE TRADE ADVANCEMENT COMMITTEE'): 'stainless steel tube trade advancement committee',
#  ('01904ac8-a455-5a52-8af3-64aa2fdd630b',
#   'GREEN EDUCATION FOUNDATION'): 'green education foundation',
#  ('01ae6c48-2f18-5946-b447-1fa9f33f547f',
#   'KEEP EASTMORELAND FREE'): 'keep eastmoreland free',
#  ('01b62795-2e3f-5f0c-94ea-1dc048f3a178',
#   'HUMAN CARE SERVICES'): 'human care services',
#  ('01baea28-4643-5c42-a2fa-4ff22e397af8',
#   'NATIONAL STEM CELL FOUNDATION'): 'national stem cell foundation',
#  ('01cd4585-2ec6-5517-8aaf-6b68bd73e59c', 'OMEGA OPTICAL'): 'omega optical',
#  ('01cd6979-808d-524f-9560-c81f24e6f56a',
#   'THE RESEARCH FOUNDATION FOR THE STATE UNIVERSITY OF NEW YORK'): 'research foundation for state university of new york',
#  ('01d6d1f5-b0e5-55c3-a819-9f4e1b653443',
#   'MODULAR WIND ENERGY, INC.'): 'modular wind energy',
#  ('01df7fd1-8ad0-506c-b16c-78541793685b',
#   'CASITAS MUNICIPAL WATER DISTRICT'): 'casitas municipal water district',
#  ('01e6dae5-1f78-5468-902e-3ef3d1641a4a', 'INTRALOOP, INC.'): 'intraloop',
#  ('01eed210-1dc1-568d-a20c-71c16f3aab23',
#   'JUSTICE FELLOWSHIP'): 'justice fellowship',
#  ('01f4575c-9d30-5a27-9148-29e8233f9fe1',
#   'HURST - EULESS - BEDFORD INDEP SCHOOL DISTRICT'): 'hurst - euless - bedford indep school district',
#  ('021cde7d-6c08-53e3-9dbe-0223749c058e', 'DOE RUN CO'): 'doe run',
#  ('021e03e7-2b5e-5ab4-822a-70bf86f001d3', 'SHIKIBO, LTD'): 'shikibo',
#  ('022cdad3-5493-5d0b-abfc-1672547e797c',
#   'BROWN & WILLIAMSON TOBACCO CORP'): 'brown williamson tobacco',
#  ('023501d1-97db-58af-826f-65c02ecbe126', 'INTL FCSTONE INC.'): 'intl fcstone',
#  ('023a440a-d5f7-59b2-b6fa-f03d83dc0aa6',
#   'BOGERT INTERNATIONAL'): 'bogert international',
#  ('0244e76f-3b34-52a3-9831-8fbb875bac3d',
#   'SF HISTORICAL SOCIETY'): 'sf historical society',
#  ('024f253d-bc83-5f61-b025-ac2509ccffee',
#   'ATLAS COPCO NORTH AMERICA LLC'): 'atlas copco north america',
#  ('02568334-9918-5f5e-98e9-f834ddcfe908', 'AIDS INSTITUTE'): 'aids institute',
#  ('028d811d-ca25-5528-bc09-fcd7dd24ec8e',
#   'ARCHDIOCESE OF WASHINGTON'): 'archdiocese of washington',
#  ('02936318-bda3-5931-9ea8-cb279a569852', 'EVANS & CO AF'): 'evans af',
#  ('0298165e-3a0f-51f6-a7fb-42750ba710a9',
#   'PINE GATE RENEWABLES, LLC'): 'pine gate renewables',
#  ('02adfb74-ab94-5178-b63e-3f1eb7926aaf',
#   'LAKE ELSINORE UNIFIED SCHOOL DISTRICT'): 'lake elsinore unified school district',
#  ('02b7beeb-2969-5477-ac60-91306c1e064b',
#   'CALIFORNIA CABLE & TELECOMMUNICATIONS ASSN'): 'california cable telecommunications assn',
#  ('02c8c599-6e42-548b-b328-158bc67322f9',
#   'SYNIVERSE TECHNOLOGIES INC'): 'syniverse technologies',
#  ('02d02e19-b3b4-5462-8711-4ad460685374',
#   'TRANSCI LOGISTICS'): 'transci logistics',
#  ('02de71ca-fd40-5119-9125-f2d2e0e21943', 'BLNG'): 'blng',
#  ('02f19757-6d8f-5e8e-86d2-f36c771b323e',
#   'ROANOKE ONLINE LLC'): 'roanoke online',
#  ('02f5effe-20b9-5b91-a858-04b823ba2154',
#   'BECK DISASTER RECOVERY INC'): 'beck disaster recovery',
#  ('02f7b23b-fd30-56af-bc62-1e092e4c43ea', 'NUTECH 03 INC'): 'nutech 03',
#  ('030ca5c8-2017-5a83-9b99-22dd2129d2b1',
#   'WESTAR AEROSPACE & DEFENSE GROUP'): 'westar aerospace defense',
#  ('030ebf1a-2290-5d68-9068-16c9d7f86471',
#   'PHILADELPHIA SOCCER 2026'): 'philadelphia soccer 2026',
#  ('03148eb3-cde2-54f1-97b7-3e04171837cb',
#   'STOPIT SOLUTIONS'): 'stopit solutions',
#  ('0316694a-b0f5-56fc-a701-7cdb7abd0bc4', 'ANSAC'): 'ansac',
#  ('0320ee44-d70c-5027-a9a5-56d5eaa66c02',
#   'SCHOOL DISTRICT OF PALM BEACH COUNTY FLORIDA'): 'school district of palm beach county florida',
#  ('03219ffc-8c40-540f-b8a3-6737ba256c9b',
#   'RAPID RATINGS INTERNATIONAL INC.'): 'rapid ratings international',
#  ('032ea5af-e826-5143-8ffb-73637f1584d9',
#   'FIBER OPTIC SENSING ASSOCIATION'): 'fiber optic sensing association',
#  ('033eeef3-ac3c-5674-ad58-5873962e39da',
#   'GOLBORNE ENTERPRISES'): 'golborne enterprises',
#  ('03460384-4883-5800-b465-2fdb07a773e4',
#   'TULALIP TRIBES OF WASHINGTON'): 'tulalip tribes of washington',
#  ('034fae9b-2008-5d02-9125-c9f3ab5a79ec',
#   'MAGNOLIA RIVER (OPTIMAL GEOSPATIAL)'): 'magnolia river (optimal geospatial)',
#  ('035096b7-2620-5f6e-bfd1-8d1bd2a47cdd', 'AQUA GREEN, LLC'): 'aqua green',
#  ('03571f92-b7d7-57a6-9c63-0893ed53ec24', 'ID EXPERTS'): 'id experts',
#  ('035c7803-53b6-5b2b-955a-2ebcb1a97901', 'ECHODYNE, INC.'): 'echodyne',
#  ('035e31ee-e009-553a-88e3-48dd3d4bbbcc', 'CIPLA USA, INC.'): 'cipla usa',
#  ('03791b4c-2ea0-5364-979b-d3608dbb6ff6', 'EZENIA'): 'ezenia',
#  ('038af051-3fe0-5fd9-8d64-e86e13e0b26a',
#   'TEMSCO HELICOPTER'): 'temsco helicopter',
#  ('03a69f17-2b4d-5507-9da8-4f35d87e8b04',
#   'CLASS ACTION FAIRNESS COALITION'): 'class action fairness coalition',
#  ('03ad87d5-3dff-5016-a5fd-23d2795d2aba',
#   'NATIONAL ASSOCIATION OF FREESTANDING EMERGENCY CENTERS (NAFEC)'): 'national association of freestanding emergency centers (nafec)',
#  ('03b21208-e8af-51ad-bc4b-2654827bfc09', 'SOLUGEN INC'): 'solugen',
#  ('03bd2265-7b7a-5d21-97df-425ab853ab9b',
#   'FLORIDA FARM BUREAU FEDERATION'): 'florida farm bureau federation',
#  ('03c02ad3-3012-556f-a7fd-a07cf5e908d7', 'UNUM GROUP'): 'unum',
#  ('03ca743e-f5d8-5b1f-be1a-ab9ed48edffa', 'SPACEDATA INTL'): 'spacedata intl',
#  ('03d2a98f-b2d9-57a5-9833-cc1d1adc05d0', 'CRYOSHAPE, LTD'): 'cryoshape',
#  ('03d5a9d7-0bfb-5fdb-a854-9a750fca2fe8',
#   'TRANSACTION NETWORK SERVICES, INC.'): 'transaction network services',
#  ('03d9980a-f797-5948-857d-bf81e46c8296',
#   'JEDWARDS INTERNATIONAL, INC.'): 'jedwards international',
#  ('03df5cd3-17b2-5a48-b54f-6c7a1e819fdd',
#   'AMERICAN AGRICULTURAL MOVEMENT'): 'american agricultural movement',
#  ('03df80cd-3445-5b99-a798-746d88de428b',
#   'INSTITUTE FOR SUSTAINABLE INFRASTRUCTURE'): 'institute for sustainable infrastructure',
#  ('03e29d63-a282-580a-9894-5a7d72055a0c', 'ATHERSYS INC'): 'athersys',
#  ('03ea4ca7-91c9-5a38-be4b-7e66a47b38ba',
#   'HEALTH & ENVIRONMENTAL FUNDERS NETWORK LEAD FUNDERS ACTION NETWORK'): 'health environmental funders network lead funders action network',
#  ('03ef6a07-e16c-59d0-8ba7-33049283a1a7',
#   'PORTALS DEVELOPMENT ASSOC LTD PARTNERSHIP'): 'portals development assoc partnership',
#  ('03f48054-92f7-54c6-91b0-78cb8be88b19',
#   'TURFGRASS PRODUCERS INTERNATIONAL'): 'turfgrass producers international',
#  ('04041942-9849-5e9c-98e2-ea35bcfd8b47',
#   'CITY OF MONTICELLO INDIANA'): 'city of monticello indiana',
#  ('04269509-126b-5adb-90fc-8e42357dfb05',
#   'FREESPACE COMMUNICATIONS'): 'freespace communications',
#  ('04481e97-d73f-5682-ac45-d431d09f4662',
#   'AUNTIE LITTER, INC.'): 'auntie litter',
#  ('04505108-9e1f-5a3c-a002-8216c365abd5',
#   'GEORGIA CANCER COALITION'): 'georgia cancer coalition',
#  ('04559b1f-d2ae-5ac4-b546-b76007243da1', 'CARDIODYNAMICS'): 'cardiodynamics',
#  ('045b86a4-eaf1-5b26-840b-c4a1ab36685c',
#   'WICKEDCOOLSTUFFCOM'): 'wickedcoolstuffcom',
#  ('046f409b-7d44-5eba-a8d6-5c86377c5faa',
#   'GLOBAL ELECTRONICS LIMITED'): 'global electronics limited',
#  ('0471ecb7-7d6f-5a6f-8cc2-90b495fa2910', 'AMERICASMART'): 'americasmart',
#  ('047f318c-c7ea-5916-9962-4ac2b7f5593e',
#   'INTL TRADE RESOURCES GROUP'): 'intl trade resources',
#  ('04813e83-ce72-5ac6-b129-6dfb140ad86c',
#   'LOCAL GOVERNMENT RESOURCES INSTITUTE'): 'local government resources institute',
#  ('048f110c-340a-548b-9a37-1cce1d391892', 'SHINTECH, INC.'): 'shintech',
#  ('049c3e30-49d1-547f-bb5a-7f52b95b8d16',
#   "NORTH AMERICA'S BUILDING TRADES UNIONS"): "north america's building trades unions",
#  ('04b71ebc-52f0-5b45-b82b-bf7b0846577a',
#   'PHEASANTS FOREVER'): 'pheasants forever',
#  ('04b839c2-6aca-528c-a1c8-309395ff0986',
#   'GOOD SHEPHERD HOME'): 'good shepherd home',
#  ('04c8c1af-4e5c-5d69-81bd-513e9eb9ed7e', 'THISTLE FARMS'): 'thistle farms',
#  ('04db091c-e943-5a31-bbee-dc1886a7d900', 'BMH ASSOC'): 'bmh assoc',
#  ('04e5ae68-4404-5c55-b356-f3edd66d7b30',
#   'AMERICAN CHEMICAL SOCIETY'): 'american chemical society',
#  ('04f6824c-39df-55bb-994a-bd20e28bcb31', 'CMT INC.'): 'cmt',
#  ('04f84654-abf2-5267-be91-46892ac226b2',
#   'PERFORMANCE BASED BUILDING COALITION'): 'performance based building coalition',
#  ('04ff838f-02b5-5c9a-bb67-45afc234dbef',
#   'SCHAEFFLER GROUP USA INC.'): 'schaeffler usa',
#  ('04ffbd6e-35b1-5c67-a6df-7a81059333f8',
#   'CENTRAL COAST COALITION'): 'central coast coalition',
#  ('0500e753-4d9c-55e0-b17f-b580e20343c3',
#   'KLAMATH COUNTY COMMISSIONERS'): 'klamath county commissioners',
#  ('050ab1dc-a210-50f2-912a-293c3222a76d', 'JAN-PRO'): 'jan-pro',
#  ('050c438a-65f8-596e-82df-b496460a6e75', 'REMBRANDT INC.'): 'rembrandt',
#  ('050dd428-7d1a-526b-b51d-aeca7ebf28e9',
#   'MATCH ENTERPRISES'): 'match enterprises',
#  ('05112517-e6c0-5545-be41-34eb60756c3c', 'LIFECARE 2.0, LLC'): 'lifecare 20',
#  ('051c3513-a516-5533-99e2-5b6984a60be9',
#   'COMMUNITY CARE OF OKLAHOMA'): 'community care of oklahoma',
#  ('051ce92c-1d51-59c4-837f-aa6685e825d1',
#   'NATL SERVICE LEARNING PARTNERSHIP'): 'natl service learning partnership',
#  ('051ed478-2091-5f26-a8c7-ed9d9b87cc01',
#   'NORTH AMERICA TRADING TOGETHER (NATT)'): 'north america trading together (natt)',
#  ('052fb5bb-ed91-56c3-8f1f-b71aba460187',
#   'VILLAGE OF BEDFORD PARK'): 'village of bedford park',
#  ('05368d35-ba85-5c91-ae34-bed57febe436',
#   'MOLNLYCKE HEALTH CARE'): 'molnlycke health care',
#  ('054c236b-9ff3-58fb-986c-d92a309051a2',
#   'LATHROP & GAGE ON BEHALF OF BRIDGETON LANDFILL LLC AND ROCK ROAD INDUSTRIES I'): 'lathrop gage on behalf of bridgeton landfill rock road industries i',
#  ('0553bee9-083b-5390-ba6c-fbe3b3276735', 'HARRIS JEWELRY'): 'harris jewelry',
#  ('0554208b-1c6b-5005-8aeb-0f757d6711ef',
#   'TAYLOR DEVELOPMENT & LAND CO'): 'taylor development land',
#  ('05609467-bddb-5ecd-91f0-18c85311a2b1',
#   'B. BRAUN MEDICAL INC.'): 'b braun medical',
#  ('05637099-1633-555b-b72c-28f613432557',
#   'FIRST GRAYSON BANCSHARES'): 'first grayson bancshares',
#  ('058181da-fe51-5a3f-95cb-39f196335a86', 'WILLIAM F. WELD'): 'william f weld',
#  ('059b74cf-a0e0-5f8b-93a7-74cf522e9744',
#   'CONCORD ASSOCIATES'): 'concord associates',
#  ('05af12c9-2fd5-51ea-8b63-51e728475a3e',
#   'CONTRARIAN CAPITAL MANAGEMENT, LLC'): 'contrarian capital management',
#  ('05af4cd9-add2-5ea5-b5aa-5ebc5e737b37',
#   'SANTEE SIOUX TRIBE OF NEBRASKA'): 'santee sioux tribe of nebraska',
#  ('05c88c0b-49bf-5a9d-b878-e627d8a00423',
#   'EDISON PRESERVATION FOUNDATION'): 'edison preservation foundation',
#  ('05e1caf3-e3c0-547d-9876-8f22cc52308e', 'SPECTRE AI INC'): 'spectre ai',
#  ('0617a7f2-d5c8-5506-bf70-f5543aced4cc',
#   'AUTOCON TECHNOLOGIES INC.'): 'autocon technologies',
#  ('06211c27-0f37-55cf-b4ca-7719b6640dc9', 'CHIMES'): 'chimes',
#  ('06598a5c-c29b-5c86-af8d-7d124ad41c3b', 'MAIL BOXES ETC'): 'mail boxes etc',
#  ('065d5788-88ed-5897-8b68-e624d199014d',
#   'CITY OF LANCASTER PA'): 'city of lancaster pa',
#  ('0663cbc7-9061-539f-8dcf-6ea20eebb7a3',
#   'ALL HOME, A PROJECT OF TIDES CENTER'): 'all home a project of tides center',
#  ('0667eb0c-7006-5e96-b20e-1e03734ead32',
#   'GREAT LAKES WATER AUTHORITY'): 'great lakes water authority',
#  ('06a06ea3-3ac3-51a4-945a-2424435a08c5', 'LIVING CITIES'): 'living cities',
#  ('06a9b753-b12c-57ed-ac0d-54fa9f00674e',
#   'PRECIOUS METALS RETAILERS ASSOCIATION (PMRA)'): 'precious metals retailers association (pmra)',
#  ('06acae4a-4ba5-5ac1-8edd-dcae55e2dfc8', 'PS COM'): 'ps com',
#  ('06b82513-077c-5ba9-873a-6e6fa0065268',
#   'BAYLOR COLLEGE OF MEDICINE'): 'baylor college of medicine',
#  ('06bbd7fc-da72-543b-9a1c-d199586a910a',
#   'THE ORIGINS PROGRAM'): 'origins program',
#  ('06c4be60-9be8-5da3-9e0c-7b162a6560cf', 'PALINDROMES, INC.'): 'palindromes',
#  ('06dc006b-76f3-532e-aa54-42440d67bf5b',
#   'HAYES LEMMERZ INTERNATIONAL, INC.'): 'hayes lemmerz international',
#  ('070469bf-659e-54e4-b10e-b4791c73cde1', 'ROCK SCHOOL'): 'rock school',
#  ('0713204e-def4-581a-bd51-9086f6e12b72',
#   'MCKEON GROUP, LLC (ANTELOPE VALLEY TRANSIT AUTHORITY)'): 'mckeon (antelope valley transit authority)',
#  ('0713f6c1-fd2b-5f1b-8c78-14307704cf5b', 'JLN SOLAR'): 'jln solar',
#  ('0714556f-7b14-53b0-a7dd-a79c9c6c22b8', 'CELULARITY, INC.'): 'celularity',
#  ('07193988-d1b9-56d1-a5e6-51033e65db2e',
#   'MISSISSIPPI STATE UNIV'): 'mississippi state univ',
#  ('072a4b15-ce9c-5320-ba21-dc57a6c378c6',
#   'FIDELITY ENGINEERING INC'): 'fidelity engineering',
#  ('072cdabf-0715-5081-a7d8-12d9b2c989fb',
#   'SUSQUEHANNA VALLEY HEALTH SYSTEM'): 'susquehanna valley health system',
#  ('0732bb33-4a13-5af9-a3a7-5d2a25d2d2fe',
#   'PROMEDICA HEALTH SYSTEM'): 'promedica health system',
#  ('073cfbaf-cc7d-56fb-ba5e-cfeec60348c3',
#   'UNIDEN AMERICA CORP'): 'uniden america',
#  ('0741d499-1afe-5fdf-bc3c-bdd2cfb06746',
#   'ARMED SERVICES YMCA'): 'armed services ymca',
#  ('0749b288-e2df-59b1-afed-7fa5b8b5cf91',
#   'RADIAL ENGINE INC.'): 'radial engine',
#  ('074ecae2-4da1-5f2a-85a3-b4d400db6cb2', 'TENNIS CHANNEL'): 'tennis channel',
#  ('07711e3c-b83f-5a72-9745-bb4eb283bd20', 'FEDCAR COMPANY LLC'): 'fedcar',
#  ('07793dad-5dcf-5f42-9ead-927d84ef5372', 'ALLKEM LIMITED'): 'allkem limited',
#  ('0789b8be-ad91-53b8-98a8-dd06e3af9e4d',
#   'CITY OF WHEELING, WV'): 'city of wheeling wv',
#  ('07910f73-1acc-535a-ad4a-d616fada1fed',
#   'ABILITY BEYOND DISABILITY'): 'ability beyond disability',
#  ('07949134-beb0-5c27-a20c-d06f6d11ff0d',
#   'EMBASSY OF THE FEDERAL REPUBLIC OF SOMALIA'): 'embassy of federal republic of somalia',
#  ('07b37f30-2e7d-54dd-8d65-9349e31c8863',
#   'COUNCIL-SUPERCONDUCTIVITY FOR AMERICAN COMPETITIVE'): 'council-superconductivity for american competitive',
#  ('07b5f43b-0b40-594c-90d7-c0d097a93fcc',
#   'BASALT ENGINEERING LLC'): 'basalt engineering',
#  ('07be99a8-edcb-51e4-8a14-78bb3688fdd7', 'NUTANIX'): 'nutanix',
#  ('07c101c9-8807-52fe-910c-0146a674aef5',
#   'STEADMAN PHILIPPON RESEARCH INSTITUTE'): 'steadman philippon research institute',
#  ('07d9c9d6-dcb0-522c-8ac2-b5315865b9ed',
#   'GROWER INFORMATION SERVICES COOPERATIVE'): 'grower information services cooperative',
#  ('07e0d83c-b219-5693-a41b-97a3cf00aab4',
#   'GLENCAIRN BRODCASTING PROPERTIES'): 'glencairn brodcasting properties',
#  ('07e72a7a-4927-5f1d-b22a-0711e81b7033',
#   'FEMINIST MAJORITY THE'): 'feminist majority',
#  ('07efb630-d968-5282-8621-d41d0933ea3d', 'STATE CHAMBER'): 'state chamber',
#  ('07f56b1c-a89f-5b54-9d40-17b8e40c210c', "O'KEEFE'S, INC."): "o'keefe's",
#  ('07f96acf-2ff2-5a99-b4d6-709804635de5',
#   'NATIONAL COALITION FOR ASSISTIVE AND REHAB TECHNOLOGY'): 'national coalition for assistive rehab technology',
#  ('07ff155a-9a02-55b4-bff2-517d650c0358',
#   'WATCO COMPANIES, LLC'): 'watco companies',
#  ('08110c0d-8353-560d-a147-481a92a89000',
#   'YOUTH LIFE FOUNDATION'): 'youth life foundation',
#  ('08304b79-df44-50a1-9e86-061dc19a49d3', 'MESA ROBOTICS'): 'mesa robotics',
#  ('08370bae-9fbb-5253-aba2-313641dc63c7', 'TERRASCALE'): 'terrascale',
#  ('08390067-f664-5cc6-bb59-623aed97a291',
#   'PRATT INSTITUTE'): 'pratt institute',
#  ('083b2619-2f05-5163-aa37-0295954f6722',
#   'AFL-CIO WORKING FOR AMERICA INST'): 'afl-cio working for america inst',
#  ('083f8d7d-b391-57aa-9696-428b6f397ef8',
#   'RURAL TELEPHONE FINANCE COOPERATIVE (RTFC)'): 'rural telephone finance cooperative (rtfc)',
#  ('08461390-4049-56b4-bd17-ca785d03a516',
#   'AMERICAN INDEPENDENT DAIRY ALLIANCE'): 'american independent dairy alliance',
#  ('0848b57f-3677-5bec-b0eb-ccf48e71122b',
#   'COPE CONSULTING'): 'cope consulting',
#  ('0850cc58-3984-5664-b4fd-da967797bba4',
#   'SUPERIOR AVIATION BEIJING CO. LTD., NO. 11, JINGHAISAN ROAD'): 'superior aviation beijing no 11 jinghaisan road',
#  ('0862aa8e-41d9-5efb-a45e-2e4a1ebfde85',
#   'MONTEREY FINANCIAL SERVICES'): 'monterey financial services',
#  ('086df19b-5dc9-5b3d-a7c5-f6d9f3b4c683', 'E-LOAN'): 'e-loan',
#  ('086e0d45-c568-5621-b461-ac61afd54842', 'LEPRINO FOODS'): 'leprino foods',
#  ('08704eb6-ca61-5194-80c0-a3b2042c1e8a',
#   'CJW QUANTUM CONSULTING, LLC'): 'cjw quantum consulting',
#  ('087d5a63-9075-5170-a7a3-cd6a0f4f66e2',
#   'MENORAH HOME & HEALTH'): 'menorah home health',
#  ('088dc67c-ec5b-5cb8-8589-5a832f934ba7', 'PERSIVIA, INC'): 'persivia',
#  ('089b6470-eb54-5434-8ac1-02a926d59c67',
#   'ANSON BANCSHARES'): 'anson bancshares',
#  ('08a19bbe-4457-5662-a4c6-ff3c04c0b1e1',
#   'GREENBRIER COMPANIES'): 'greenbrier companies',
#  ('08ac8f75-2436-50d8-a1bc-c15564ff9d2f',
#   'VILLAGE OF DEER PARK, ILLINOIS'): 'village of deer park illinois',
#  ('08b361e1-eb1c-57e6-ab11-f2ebd699d4fa',
#   'COMMUNITY JUSTICE ACTION FUND'): 'community justice action fund',
#  ('08b530bd-32d5-5033-8d7c-07d06d024570', 'PROAVIH'): 'proavih',
#  ('08b6d3f0-fe6f-5839-af35-f72c4e52b67c',
#   'OCH-ZIFF CAPITAL MANAGEMENT GROUP LLC'): 'och-ziff capital management',
#  ('08c05c57-3bff-5a46-b5e4-fcabf1b82ab6',
#   'ENNIS FRANCES JOAN'): 'ennis frances joan',
#  ('08cd7f66-9677-54c8-ad76-fab8e86ddde2',
#   'SOUTH AFRICAN FRUIT & VEGETABLE CANNERS ASSN'): 'south african fruit vegetable canners assn',
#  ('08dfb729-5f42-5937-a064-fb50b478f9c7',
#   'AMERICAN SOCIETY OF COMPOSERS, AUTHORS AND PUBLISHERS (ASCAP)'): 'american society of composers authors publishers (ascap)',
#  ('08e08a32-debc-56e9-a193-8c79f7c4d17d',
#   'AUTEL AUTOMOTIVE INTELLIGENCE USA'): 'autel automotive intelligence usa',
#  ('08e2ac31-9fe3-5f4c-b520-2fdfaf5c1400',
#   'THE MITCHELL FIRM, INC.'): 'mitchell firm',
#  ('08e86304-daa1-5dd4-89bb-0f31e65e545b', 'WORLD LEARNING'): 'world learning',
#  ('08f1e793-b471-5a37-a151-314e07027c2c', 'INTERSECTIONS'): 'intersections',
#  ('08f39ff9-4e2c-5172-86e3-9a0c0ee1a3e7',
#   'NEUROS MEDICAL, INC.'): 'neuros medical',
#  ('08fdb586-a6b6-54b6-8d8b-5abca5b5d883',
#   'VILLA RESTAURANT GROUP'): 'villa restaurant',
#  ('0905c4ef-07a1-5f42-b49c-abaa92a7baf4', 'CBT NUGGETS'): 'cbt nuggets',
#  ('091975de-6415-5c44-9fd4-3ad26786c7f8', 'RVJ CAPITAL'): 'rvj capital',
#  ('0c30bbcc-119d-5531-bd6e-4e17e08d997a', 'FIBERGATE'): 'fibergate',
#  ('092cd23d-ced5-57cb-bf13-d395ec514aef',
#   'TUOLUMNE PUBLIC POWER AGENCY'): 'tuolumne public power agency',
#  ('09467ba6-0b9b-5440-a30b-698045bd4f6b',
#   'CAPE PRODUCTIONS, INC.'): 'cape productions',
#  ('094716fd-989a-57e8-8420-5d11d45e3ae8',
#   'REMINGTON MEDICAL RESORTS'): 'remington medical resorts',
#  ('096fecf7-3691-5530-9c12-9a2e00b8ed4d', 'THE BILTMORE COMPANY'): 'biltmore',
#  ('09726753-9e41-5a7d-8eaa-84e34cc3d6e4',
#   'ETHIOPIAN AMERICAN CIVIC COUNCIL'): 'ethiopian american civic council',
#  ('09735992-b011-5d65-bddc-bdfcb6cf4c30',
#   'VERIFIED VOTING'): 'verified voting',
#  ('0982f274-cb00-513e-af9d-c0c686bb1a0e',
#   'THE WILLIAMS GROUP FOR SUSTAINABLE SCHOOL RESOURCES LLC'): 'williams for sustainable school resources',
#  ('098301c1-4da6-50aa-9e8c-ab3e2fb8df78', 'QUSECURE'): 'qusecure',
#  ('099b5b11-d121-56ef-a6ee-68e886846557',
#   'INTERCELL USA INC'): 'intercell usa',
#  ('099ff0de-f8c3-5119-b5f0-188754363b01',
#   'BURROUGHS AND CHAPIN COMPANY INC'): 'burroughs chapin',
#  ('09bb3e45-0e27-549e-baca-a5a3bc8896c7',
#   'BROOKWOOD COMPANIES INCORPORATED'): 'brookwood companies incorporated',
#  ('09bf1fe1-17c7-5e0b-8711-bf12048e31b2',
#   'CATAWBA COUNTY NC'): 'catawba county nc',
#  ('09cace18-8b69-517a-9ece-c69c419d250a',
#   'FARM CREDIT SOUTH FLORIDA'): 'farm credit south florida',
#  ('09d0e063-ee6b-51e7-8d59-14add26c5e6d',
#   'HARLOW GOVERNMENT RELATIONS'): 'harlow government relations',
#  ('09e3ee21-9312-553b-8ea5-b9ab70fd090b', 'USA FUNDS INC'): 'usa funds',
#  ('0a078e82-ded0-5f83-b52c-02e000a5dde3',
#   'MAS-HAMILTON GROUP'): 'mas-hamilton',
#  ('0a12c434-dba8-5734-8bdd-270fe8de5dfa',
#   'AMERICAN BIOCARBONS, LLC'): 'american biocarbons',
#  ('0a1a25fc-8f40-5674-a7e2-9002741a0030',
#   'JEWISH ASSOCIATION FOR RESIDENTIAL CARE'): 'jewish association for residential care',
#  ('0a1f1755-57b3-58d8-b859-ddddb32bf645', 'HOV SERVICES, INC'): 'hov services',
#  ('0a22f455-8f27-573f-a6ed-33594ed17aa4',
#   'TRIANGLE TRANSIT AUTHORITY'): 'triangle transit authority',
#  ('0a27be7f-8a14-5fe4-a6cd-4e17e459301c',
#   'TECHNICAL CAREER INSTITUTES'): 'technical career institutes',
#  ('0a33afc3-76bb-5f2f-aa41-da89655e6783', 'MEDIAN WIND LLC'): 'median wind',
#  ('0a453a60-de37-5783-a26a-4181027bde90',
#   'SKYBRIDGE LTD PARTNERSHIP'): 'skybridge partnership',
#  ('0a53b9c7-6e3f-569e-95c3-8576d9a72dec',
#   'AMETEX, AMERICA TEXTIL S.A.'): 'ametex america textil sa',
#  ('0a7ae145-1e33-56f6-843e-4a660424a343',
#   'CHITIMACHA TRIBE OF LOUISIANA'): 'chitimacha tribe of louisiana',
#  ('0a7dba96-6afa-5855-8c53-bea7bc4d0f36',
#   'ALN ENTERTAINMENT GROUP INCORPORATED'): 'aln entertainment incorporated',
#  ('0a8499b4-3b5b-5bd3-90cb-602e76fa0f95',
#   'DETROIT STEEL CORP'): 'detroit steel',
#  ('0a869d28-186f-5351-8603-5ea66d1b9459',
#   'ZERCO SYSTEMS INTERNATIONAL, INC.'): 'zerco systems international',
#  ('0a8f4d45-bd15-5e5d-b09f-7e4800b397a4',
#   'AMKOR TECHNOLOGY'): 'amkor technology',
#  ('0a932a84-5126-5eea-a9e5-dba419ad7e1e',
#   'NATIONAL CONCRETE MASONRY ASSOCIATION'): 'national concrete masonry association',
#  ('0aa0f374-0586-5f4f-9168-eddc44047b2c', 'WORLD ENERGY'): 'world energy',
#  ('0aaddabc-9ba5-5b6d-902c-aa07a5b55740',
#   'CITY OF BLOOMINGTON IN'): 'city of bloomington in',
#  ('0abc5551-2dad-501a-96a7-6fc349e4c72e', 'WISH'): 'wish',
#  ('0ac23124-261e-533f-9355-9bd9406c1774',
#   'VICKERS & NOLAN ENTERPRISES'): 'vickers nolan enterprises',
#  ('0ac35e8e-0e09-58d3-be8b-24964b8bf0f5',
#   'EQUITAS LIMITED'): 'equitas limited',
#  ('0ac726ec-71bb-5ef1-8153-a9561ef7bad6',
#   'ALLADVANTAGECOM'): 'alladvantagecom',
#  ('0ad25f9e-513d-5ea8-bcb4-dc06cfd88740',
#   'ARETE ASSOCIATES'): 'arete associates',
#  ('0ae42d70-1673-52e5-8ede-de2e71d45c08',
#   'SABIC INNOVATIVE PLASTICS US LLC'): 'sabic innovative plastics us',
#  ('0ae50493-a71b-5ecf-941a-5686914fe45e',
#   'VELOCYS INCORPORATED'): 'velocys incorporated',
#  ('0aeaf1f0-c52e-57bb-9123-9098522f31c8',
#   'PROTECTINGAMERICA.ORG'): 'protectingamericaorg',
#  ('0af536ca-2d4d-5a59-a52c-c3b57db2f721', 'MODA HEALTH'): 'moda health',
#  ('0b129c1e-a3d2-56c4-9179-301d2701bc29',
#   'ASSOCIATED WIRE ROPE FABRICATORS'): 'associated wire rope fabricators',
#  ('0b17a40a-127f-57d9-889f-dcd8dc5f8f51',
#   'NORTH DAKOTA MOTOR CARRIERS ASSOCIATION'): 'north dakota motor carriers association',
#  ('0b3b66c3-4213-52a7-8039-753486360b80',
#   'PROTEIN SCIENCES CORPORATION'): 'protein sciences',
#  ('0b3e3be5-ec26-5e6b-8412-e5075891793f',
#   'FISHER INVESTMENTS'): 'fisher investments',
#  ('0b3ea739-f806-5bd8-a20b-5c8dafad0075', 'ZOLTEK CORPORATION'): 'zoltek',
#  ('0b442ed2-f41c-5b75-be7e-c8bdd0a5248d',
#   'ENVIRONMENTAL COMMON SENSE'): 'environmental common sense',
#  ('0b456642-f9c6-5bf6-8bad-b80b6c485c5a',
#   'CARDTRONICS USA, INC.'): 'cardtronics usa',
#  ('0b4f5d0d-3d65-5f22-a385-ff95d38f8d97',
#   'BUSINESS COUNCIL OF NEW ORLEANS'): 'business council of new orleans',
#  ('0b5a74cc-1716-544c-978c-5446b616503a',
#   'PLUMAS LAKE LANDOWNERS/BIA'): 'plumas lake landowners/bia',
#  ('0b5a8dec-8478-5f74-a276-10f0b15d8c90', 'PHENOME HEALTH'): 'phenome health',
#  ('0b69db68-71fd-59fa-acf0-8fba8e8f433c', 'FLIGHTCOM CORP'): 'flightcom',
#  ('0b77939b-816b-503a-9d3f-332694e0d231',
#   'WHITE PINE ENERGY ASSOCIATES'): 'white pine energy associates',
#  ('0b812f57-e196-5ef8-a970-8a3ab53e95c9',
#   'BELLA AUTOMOTIVE GROUP'): 'bella automotive',
#  ('0ba0ae12-7487-5f52-98a4-a7470ac758a6',
#   'POLYESTER FIBERFILL ASSOCIATION'): 'polyester fiberfill association',
#  ('0ba158c2-b8df-5a9b-b679-7c69985701a0',
#   'VERILY LIFE SCIENCES LLC'): 'verily life sciences',
#  ('0badd8db-cdbb-5e22-9f36-aada612323ee', 'LT FOODS'): 'lt foods',
#  ('0bafbeeb-6fbd-5703-8a90-6c72b621c42a',
#   'PORT OF LONG BEACH'): 'port of long beach',
#  ('0bc3043c-20fe-55cd-978f-e925dca673a9',
#   'BIG BROTHERS BIG SISTERS MIDDLE TENNESSEE'): 'big brothers big sisters middle tennessee',
#  ('0bc5fe20-68d3-516d-b838-66998ee32aee', 'FITCH GROUP, INC'): 'fitch',
#  ('0bd45391-c9a5-54ec-8eca-58c20c7a2474',
#   'NORTHPOINT DEVELOPMENT'): 'northpoint development',
#  ('0bd849f9-ade0-56af-9ba4-2b7d2f21f05a',
#   'SENTINEL SATELLITE CORP'): 'sentinel satellite',
#  ('0bdb81d3-1ed5-5698-a428-57f84abbfd19',
#   'NANSEMOND INDIAN TRIBAL ASSOCIATION'): 'nansemond indian tribal association',
#  ('0bdf399c-b5a8-5d78-9bb8-1969d6e76020',
#   'RICH INNES ON BEHALF OF THE ASSOCIATION OF NATIONAL ESTUARY PROGRAMS'): 'rich innes on behalf of association of national estuary programs',
#  ('0bef4a3a-d518-52cb-b3b1-d1bd19333eb7',
#   'MATTESON SCHOOL DISTRICT 162'): 'matteson school district 162',
#  ('0bfbbdb6-5613-5496-91cc-9c576f1d30c7',
#   'COOSA VALLEY WATER SUPPLY'): 'coosa valley water supply',
#  ('0bfc2bb8-5239-565e-8685-11e4166c016a',
#   'NEW YORK/NEW JERSEY 2026 WORLD CUP HOST COMMITTEE'): 'new york/new jersey 2026 world cup host committee',
#  ('0bfdba55-ebd1-5d26-8992-352fa248e9ff',
#   'ILLINOIS DEPARTMENT OF COMMERCE ECONOMIC OPPORTUNITY'): 'illinois department of commerce economic opportunity',
#  ('0c05af94-3330-5079-a917-7e7fe0ca0dfa',
#   'CONTINENTAL CARBON NANOTECHNOLOGIES, INC.'): 'continental carbon nanotechnologies',
#  ('0c0e02d6-0163-51d5-ba11-80528a44aebc',
#   'MULLENHOLZ BRIMSEK & BELAIR'): 'mullenholz brimsek belair',
#  ('0c189c72-71db-5b0c-8a9a-1f9d7b05a672', 'WALES UNION'): 'wales union',
#  ('0c2677ee-f731-5a5f-b3a5-4cd7fc948363', 'SAILPLAN'): 'sailplan',
#  ('0c29b4ed-9fac-5224-b339-9317e869e544',
#   'SAINT MARGARET MERCY HEALTHCARE CENTERS'): 'saint margaret mercy healthcare centers',
#  ('0c339972-9b24-5c8d-9907-22125f57b138',
#   'TUALATIN VALLEY WATER DISTRICT'): 'tualatin valley water district',
#  ('0c3d624e-ea7b-57c8-9c0d-12d2261e63ac', 'FLH COMPANY'): 'flh',
#  ('0c5398f1-86cd-5ab8-9b88-37a8abb8c03a', 'EPIVAX, INC.'): 'epivax',
#  ('0c67a791-5072-5756-8302-8b045a4a9545', 'GLACIER BAY GROUP'): 'glacier bay',
#  ('0c78281f-f8a4-5a2a-a95e-96995fce69dd',
#   'HOUSING AUTHORITY OF THE CITY OF GARY IN'): 'housing authority of city of gary in',
#  ('0c7c272e-0b2f-51f1-b072-fb60a9a84f2d', 'PANCOPIA'): 'pancopia',
#  ('0c7d62c2-6f42-5150-8413-b387438c1599', 'INTL COAL GROUP INC'): 'intl coal',
#  ('0c7ecd02-a331-57e7-9d26-10712257b59d',
#   'Z DEVELOPMENT LLC'): 'z development',
#  ('0c9d5964-c354-534c-b565-5659e5f7329d',
#   'COLLEGIATE FUNDING SERVICES'): 'collegiate funding services',
#  ('0cb2aee8-1aee-529a-8db4-acc08672b566',
#   'NATL HORSE PROTECTION COALITION'): 'natl horse protection coalition',
#  ('0cc338c4-a579-5c89-95c7-4c85a46218a7',
#   'EMBASSY OF THE REPUBLIC OF PANAMA'): 'embassy of republic of panama',
#  ('0ccbe775-fca0-5698-baaa-a23cfdbe3fe7', 'MICHBIO'): 'michbio',
#  ('0cf0a0d4-8ba2-5c52-8db2-482a5632a0f8', 'ELF AQUITAINE'): 'elf aquitaine',
#  ('0cf148af-322f-53ce-904f-a6eec3723538',
#   'ROGUE VALLEY MICRODEVICES, INC.'): 'rogue valley microdevices',
#  ('0cf4b0c8-def9-5d14-a613-38fbc4edb5fa',
#   'COALITION FOR THE ADVANCEMENT OF MEDICAL RESEARCH (CAMR)'): 'coalition for advancement of medical research (camr)',
#  ('0d1c74ca-04b6-53c8-8d0f-96d065db33c9',
#   'NATIONAL ACTIVE AND RETIRED FEDERAL EMPLOYEES ASSOCIATION'): 'national active retired federal employees association',
#  ('0d24bf7b-c04f-53cf-b6e0-98282f332579', 'NEWPORT CORPORATION'): 'newport',
#  ('0d36dfa9-8e18-564c-a637-4ea050e0e1af',
#   'EMCO INDUSTRIES INC'): 'emco industries',
#  ('0d5bc7ea-523e-5223-9041-a77bcca88d3b',
#   'TITUS REGIONAL MEDICAL CENTER'): 'titus regional medical center',
#  ('0d5be0d1-d61b-55a1-a661-efa8780fa7b4', 'WALGREEN CO.'): 'walgreen',
#  ('0d6be4de-896a-5817-a64e-e0bfe72651ec',
#   'VILCIAS FERDINAND'): 'vilcias ferdinand',
#  ('0d6dcf3a-a6c8-5c8c-ba1d-a11cd029c1b4',
#   'ROSALYNN CARTER INSTITUTE FOR CAREGIVERS'): 'rosalynn carter institute for caregivers',
#  ('0d785df4-6b73-5e4f-9c11-8c8b94bf1d81', 'KGL LOGISTICS'): 'kgl logistics',
#  ('0d7bb8e6-3cd4-50bb-b386-c6ba97c41a2d',
#   'NHCA - NATIONAL HOOKAH ?COMMUNITY ASSOCIATION'): 'nhca - national hookah ?community association',
#  ('0d8d75e1-a0e4-553a-965e-edaa47302dab', 'SETI INSTITUTE'): 'seti institute',
#  ('0d8fdbe6-ce5f-5386-aa4a-2558ad4a4d51', 'LIFE STEPS INC'): 'life steps',
#  ('0d983c3a-f45a-5acb-9870-e3514d73fb0f',
#   'PACIFIC NORTHWEST WATERWAYS ASSOCIATION'): 'pacific northwest waterways association',
#  ('0d993de4-2179-56fb-9c88-4aacc2d2431b', 'RV RETAILER, LLC'): 'rv retailer',
#  ('0d9c589d-6357-5aa2-af0a-221d7f228aa7',
#   'CAUTHEN FORBES & WILLIAMS ON BEHALF OF MERCK'): 'cauthen forbes williams on behalf of merck',
#  ('0d9e4ec9-1b7f-5887-a8d2-614fc7aa1fe8',
#   'ANGLICAN CATHOLIC CHURCH'): 'anglican catholic church',
#  ('0dad12da-56d5-57e4-9068-c52d67270415',
#   'RESTORATION FOREST PRODUCTS, LLC'): 'restoration forest products',
#  ('0dae991d-d7d4-570e-b833-b29d64bac2fe',
#   'BAY HARBOUR MANAGEMENT LLC'): 'bay harbour management',
#  ('0daeea06-8b94-5d72-830d-c158a0aafca5',
#   'DEEP EAST TEXAS ELECTRIC COOPERATIVE INC'): 'deep east texas electric cooperative',
#  ('0dafb4d9-d490-55cd-a4f0-4e1a3ba857ac',
#   'DINAKAR SINGH AND LOREN ENG'): 'dinakar singh loren eng',
#  ('0dbb3c0f-48ef-5801-9c25-aaf699dd797e',
#   'FLYING FOOD GROUP, LLC'): 'flying food',
#  ('0dc3ee63-f84a-507a-b656-32caac9dc57e',
#   'NORFOLK SOUTHERN CORPORATION'): 'norfolk southern',
#  ('0dc5035c-403b-5f8d-a33c-f157749e7247',
#   'REVOLUTIONARY SPACES'): 'revolutionary spaces',
#  ('0dd809a3-b73c-5f8e-b538-46c5457f65f0', 'WTC LLC, DBA LEMA'): 'wtc dba lema',
#  ('0dd93f25-5fde-52ca-9686-58046c8ab018', 'RMC 2021, LLC'): 'rmc 2021',
#  ('0ddb77d9-c175-528d-823d-e30dab70b67b',
#   'ENRON WIND CORP/ZOND'): 'enron wind corp/zond',
#  ('0ddc7a5c-819e-582f-9708-c1db7e701d89',
#   'MICHIGAN STATE UNIVERSITY'): 'michigan state university',
#  ('0de86151-d6a5-5a6b-98cd-55e12e1833e5', 'BELL ENERGY'): 'bell energy',
#  ('0dfd7bbd-2053-5195-8f50-bb8f84dda2e9',
#   'ID CONSERVATION LEAGUE'): 'id conservation league',
#  ('0e0a6963-4cf8-5d55-8873-24049e2a85c3',
#   'COUNTY OF ROBESON'): 'county of robeson',
#  ('0e0cd59e-7c25-5231-8c3a-e08dd217c821',
#   'ASSOCIATION OF PROFESSIONAL PIPELINE SURVEYORS (APPS)'): 'association of professional pipeline surveyors (apps)',
#  ('0e0e7fc4-89f6-5638-98cc-49eba69d0f22',
#   'JOSEPHINE COUNTY, OREGON'): 'josephine county oregon',
#  ('0e1995c0-d799-5733-87ea-b8654689a7bb',
#   'CANVASBACK MISSIONS INC'): 'canvasback missions',
#  ('0e19c9b0-2e06-50d1-8243-640e882264ad',
#   'CLARK ATLANTA UNIV'): 'clark atlanta univ',
#  ('0e1a0a3c-b5b7-57e7-9b93-5d29f346634b', 'JABIL, INC.'): 'jabil',
#  ('0e1ec95d-dc0f-5249-90ab-7cf9f9387b19',
#   'SHAKE-N-GO FASHION, INC.'): 'shake-n-go fashion',
#  ('0e28e934-5341-5808-b29a-48d375150d27', 'AUTHENTIC8, INC.'): 'authentic8',
#  ('0e294853-3c9b-5ab6-86e6-5ffc3f0c6543',
#   'SILICA WORKING GROUP'): 'silica working',
#  ('0e334cba-b62d-5af7-aa17-2b43b28560b9', 'WORLDSPAN'): 'worldspan',
#  ('0e384b99-5d1a-5050-bbbb-5bdb86d2f7ee', 'CYTERRA'): 'cyterra',
#  ('0e462374-fbe8-5b93-89e3-eb90ef0d9675', 'CITY OF SEATAC'): 'city of seatac',
#  ('0e55bb28-6a84-5f95-989f-37e16dfec9dc',
#   'POYNER SPRUILL, LLP ON BEHALF OF HOLDEN BEACH'): 'poyner spruill llp on behalf of holden beach',
#  ('0e598c4f-33fb-53f6-b000-bfae21dd9c14',
#   'UNIFORM SERVICES DENTAL ALLIANCE'): 'uniform services dental alliance',
#  ('0e5f5e05-fa4f-5e05-b804-53a329c68161',
#   'NAVISTAR DEFENSE, LLC'): 'navistar defense',
#  ('0e9c97b7-c53d-54ea-9111-08eb05c7c0f3',
#   "TRAIL'S END RANCH RADIO SHOW"): "trail's end ranch radio show",
#  ('0ea007a0-eebc-5262-9bd5-ce64294be7b9',
#   'SKYWAY SYSTEMS INC'): 'skyway systems',
#  ('0ea5b44d-0d5e-58e6-8ec7-ed5cddaddd66', 'CAVEL INTL'): 'cavel intl',
#  ('0eb285bb-30ae-5cd7-bb17-728f5d2ca3fd',
#   'TRANSPACIFIC WESTBOUND RATE AGREEMENT'): 'transpacific westbound rate agreement',
#  ('0eb71ca9-9cf5-5b23-8986-717b0e532ba4',
#   'CITY OF SHELBYVILLE, IN'): 'city of shelbyville in',
#  ('0ec42c9a-1484-5e31-b801-bea0995295d1',
#   'JOHNSON ENGINEERING'): 'johnson engineering',
#  ('0ecad48d-cb7e-57ec-be0f-9a7bea8d04e7', 'RESPIRONICS'): 'respironics',
#  ('0ecdca02-75dc-5870-b268-af7b63a26401',
#   'ECOSYSTEM INVESTMENT PARTNERS'): 'ecosystem investment',
#  ('0ed4b617-e30d-5212-91e4-dfc1103574b2',
#   'BELL WINSTON EVERETT'): 'bell winston everett',
#  ('0ed6f739-ce80-5913-9750-3bae99ce5c29',
#   'PREMIUM POWER CORPORATION'): 'premium power',
#  ('0ee00e3e-1d5b-5ed9-aa22-eec0a7187ee0',
#   'HOPE NETWORK FOUNDATION'): 'hope network foundation',
#  ('0ee117af-2384-58be-acf9-52c26501be90',
#   'MANHATTAN ASSOCIATES, INC.'): 'manhattan associates',
#  ('0ee14495-aea7-504f-9f4f-186f1f3e3a73',
#   'CLIPPER WINDPOWER, INC.'): 'clipper windpower',
#  ('0ee9ee2f-dcae-56a5-8c93-df7c730a3bfc',
#   '3D GLASS SOLUTIONS, INC.'): '3d glass solutions',
#  ('0eed8bb9-3f6f-513b-bc8d-42769e908d0d',
#   'SOMERSET COUNTY'): 'somerset county',
#  ('0ef6135a-7ce8-529d-bcc6-37156fd9a861',
#   "LOUISIANA CHILDREN'S MUSEUM"): "louisiana children's museum",
#  ('0efca361-cd9f-5b8e-943e-d7b5e3b2b6aa',
#   'SOUTH DAKOTA SCHOOL OF MINES & TECHNOLOGY'): 'south dakota school of mines technology',
#  ('0efe0ed9-8753-5b4f-bc83-8592d2b9ccbc',
#   'NATIONAL PECAN GROWERS COUNCIL'): 'national pecan growers council',
#  ('0f0088f4-a28b-580a-aa8c-5c39c8dccf17',
#   'TECHNOLOGY MANAGMENT INCORPORATED'): 'technology managment incorporated',
#  ('0f01d912-51a6-5c81-9912-fa0ff8e41252',
#   'ASGARD TECHNOLOGIES'): 'asgard technologies',
#  ('0f2d9ac0-4af7-549d-ac21-3190a52b8499',
#   'SOLUTION RECOVERY SERVICES'): 'solution recovery services',
#  ('0f3e2353-f70a-5c29-b9a1-035bc8612a1b',
#   'DUNRATH CAPITAL'): 'dunrath capital',
#  ('0f420ff5-8b6b-5b7e-a6de-2a1b1f780b69',
#   'TREATMENT COMMUNITIES OF AMERICA'): 'treatment communities of america',
#  ('0f4226e1-b1a1-55bd-843d-d63f8f45a1b8',
#   'BOSTON STOCK EXCHANGE'): 'boston stock exchange',
#  ('0f43e4f7-e409-50df-8f89-3b307f72535a',
#   "LLOYD'S OF LONDON"): "lloyd's of london",
#  ('0f55e6a9-25a1-58da-908c-832032abbcb3', 'ENVIROAIR LLC'): 'enviroair',
#  ('0f739ef5-2a40-5822-8e42-a069e1ccee38',
#   'LA JOLLA PHARMACEUTICAL COMPANY'): 'la jolla pharmaceutical',
#  ('0f98b75a-0d9c-568b-9577-eef9fbc66970', '422'): '422',
#  ('0f99ed06-db60-5024-9bb5-0a69f8ffb260', 'CRANE & COMPANY INC'): 'crane',
#  ('0fad706b-a0e8-541a-96b7-e674525a6278',
#   'ST. ANDREWS UNIVERSITY'): 'st andrews university',
#  ('0fce4eb0-1c29-544f-bdee-ba53e2848b9a', 'JAMES DOYLE'): 'james doyle',
#  ('0fec2a52-100c-532b-a1cd-ebe2cd2ffd32',
#   'CHARTER SCHOOL MANAGEMENT, INC.'): 'charter school management',
#  ('0ff9bf25-c8cc-5bf5-870e-f2288f2634b2', 'IDMTS, LLC'): 'idmts',
#  ('0ffab077-a9fa-5828-be25-73d4ab342cfc',
#   'ALABAMA SOUTHERN COMMUNITY COLLEGE'): 'alabama southern community college',
#  ('0ffc056d-258a-53b1-a1b0-31fea0cd207a',
#   'WELLTON-MOHAWK IRRIGATION & DRAINAGE DISTRICT'): 'wellton-mohawk irrigation drainage district',
#  ('100fcdb8-dadd-55d7-84cb-08919218a686',
#   'MALONE MORTGAGE CO'): 'malone mortgage',
#  ('10324d99-dfb6-5b74-9b68-980f420e68a2', 'PRONTO.AI, INC.'): 'prontoai',
#  ('1037c5b2-ea55-5442-ba4a-fdc62a9b9b8d',
#   'FORENSIC STRATEGIES INTL'): 'forensic strategies intl',
#  ('1038d9b2-98ba-56bc-bd7c-a02b0a15a603',
#   'NATIONAL ALLIANCE FOR PUBLIC CHARTER SCHOOLS'): 'national alliance for public charter schools',
#  ('103bc74b-2545-5ef7-8c11-70ffa580731f', 'BABY MATTERS, LLC'): 'baby matters',
#  ('103dbb03-6961-53e7-a44d-08cb9c5216a5',
#   'BIPARTISAN POLICY CENTER ACTION'): 'bipartisan policy center action',
#  ('1042af06-fc3e-543d-8b3d-e313331cc063', 'KEMP PARTNERS'): 'kemp',
#  ('104f4103-7ab2-5e6d-8fd4-b5186801d6c9',
#   'ICOP DIGITAL, INC.'): 'icop digital',
#  ('106549bb-c5a7-5a25-b45a-06f97d74a884',
#   'GLOBAL ENVIRONMENTAL ENGERY CORP (GEEC)'): 'global environmental engery (geec)',
#  ('1069f4cd-864f-54cf-be5a-97b7286f2d4a',
#   'EMPLOYEE-OWNED S CORPORATIONS OF AMERICA'): 'employee-owned s corporations of america',
#  ('10755746-ce22-5787-a884-a5d0403f1f28', 'ISN CORPORATION'): 'isn',
#  ('10776903-852f-5be7-9a2a-7de0c5d8af45',
#   'WILLOW BEND VENTURES LLC'): 'willow bend ventures',
#  ('107b1f8e-9840-5ee3-9c00-a9de5d6c4a09', 'SEASIDE CA'): 'seaside ca',
#  ('10840a9a-5eed-577a-b586-241c406830a0',
#   'FIBER TECHNOLOGY CORPORATION'): 'fiber technology',
#  ('109b22ce-97bf-5fc0-a11a-09a0a23d6c1a', 'ELMI BERISHA'): 'elmi berisha',
#  ('109fa43b-1904-57f4-8800-8f5597920afe',
#   'COMMONWEALTH EVENT SERVICES, LLC'): 'commonwealth event services',
#  ('10a4a868-c954-5ec2-a212-de555ea444c5',
#   'LEWIS INVESTMENT CO'): 'lewis investment',
#  ('10a53ac8-e091-5dad-9753-6da1e9ece37a', 'PRELUDEDX'): 'preludedx',
#  ('10a739ef-95db-5803-acf0-e748540d6e47',
#   'CALHOUN COUNT COMMISSION'): 'calhoun count commission',
#  ('10b26df7-7d83-5b81-84cf-68d94c963cdd', 'DEMOCRACY 21'): 'democracy 21',
#  ('10be838e-0ffe-52aa-bdd9-72f181d6325c',
#   'DISTRIBUTED WIND ENERGY ASSOCIATION'): 'distributed wind energy association',
#  ('10bf8177-c555-556a-893f-44d31964bba8', 'URSA MAJOR'): 'ursa major',
#  ('10c5c3f0-1ba1-5de9-a772-ae5b5a59cc2b',
#   'KAPOS ASSOCIATES INC'): 'kapos associates',
#  ('10c70d69-65b0-55dd-8354-b73020ac131d',
#   'SPAULDING & SLYE'): 'spaulding slye',
#  ('11105ad5-fbb4-5224-9aed-7bf1f15bc3d5',
#   'PUERTO RICO HOSPITAL GROUP'): 'puerto rico hospital',
#  ('10df52fc-b96e-559c-8d9c-f5e480a9dffe', 'E-LOTTERY'): 'e-lottery',
#  ('10fcede9-1a9d-5517-b8e6-c3457e43b26b',
#   'CRANBERRY MARKETING COMMITTEE'): 'cranberry marketing committee',
#  ('10fed2cc-d007-55eb-ae95-475f5b6958c5',
#   'INTERNATIONAL ALLIANCE OF THEATRICAL STAGE EMPLOYEES'): 'international alliance of theatrical stage employees',
#  ('1112df50-cce8-5045-b410-e639ada4ea4d',
#   'MAKEDONSKI TELEKOMUNIKACII'): 'makedonski telekomunikacii',
#  ('111370ff-ae6f-50ac-b215-2b00e7a4d374',
#   'CLIFTON LARSON ALLEN, LLP'): 'clifton larson allen llp',
#  ('111dc1ce-27cf-5b91-b272-845672049f11', 'VALISURE'): 'valisure',
#  ('112c3024-35c6-5a0a-9fef-837764e424bc',
#   'GOLDEN EAGLE DISTRIBUTORS'): 'golden eagle distributors',
#  ('11331e18-7157-53c1-b760-9dc181442719', 'FASTSHIP INC'): 'fastship',
#  ('11351309-45f7-5256-86be-85071c2181e7', 'CBIZ MHM, LLC'): 'cbiz mhm',
#  ('1136db54-9b84-5f7b-8852-18ea346ee8d6', 'VANE BROTHERS'): 'vane brothers',
#  ('114ee0c0-4d10-5bb6-86d7-1a5294999b2d', 'NOWSECURE'): 'nowsecure',
#  ('1158d1fc-8b61-59a6-be8b-272245a7df0f',
#   'ENERSYS DELAWARE, INC.'): 'enersys delaware',
#  ('116a314f-7825-5aa9-bd6e-918902e0b53d', 'CAMBRIDGE INTL'): 'cambridge intl',
#  ('121dbd1b-61c4-5649-ba55-5df6281e5991', 'MED EMPORIUM, LLC'): 'med emporium',
#  ('11778879-a0e3-583a-9db2-9bb0c8fb109c',
#   'BARNES & NOBLE EDUCATION, INC.'): 'barnes noble education',
#  ('11810fce-a479-5163-ae14-64312464e8d8',
#   'GUATEMALA JUSTICE FOUNDATION'): 'guatemala justice foundation',
#  ('1188787f-507e-5471-8820-f113dd3ba2fa',
#   'RETRIEV TECHNOLOGIES, INC.'): 'retriev technologies',
#  ('118e8103-6950-5d3a-901f-1d78a0f4ade9',
#   'RESTLESS LEGS SYNDROME FOUNDATION, INC'): 'restless legs syndrome foundation',
#  ('1193cbf8-edf3-5613-8717-2ef5fc82b95d',
#   'RXREVU DBA ARRIVE HEALTH'): 'rxrevu dba arrive health',
#  ('119a0364-f1b8-53e5-bf30-a729b642b955',
#   'UNIVERSAL MUSIC GROUP'): 'universal music',
#  ('11bab11f-ef43-59cf-a2e7-158ef4c5cd97',
#   'ANTELOPE VALLEY TRANSIT AUTHORITY'): 'antelope valley transit authority',
#  ('11cd6d1a-0ea8-54a2-92a9-4a3c1e99bd82',
#   'ALLIED NATURAL GAS'): 'allied natural gas',
#  ('11f92041-9ea0-59dc-a088-1e040d53d331',
#   'CONAFAY GROUP ON BEHALF OF ANTIBIOTICS WORKING GROUP'): 'conafay on behalf of antibiotics working',
#  ('11fd0c84-1858-57fc-82cc-dbbac799c2e7',
#   '49ER COMMUNICATIONS'): '49er communications',
#  ('1208bead-f32d-5d20-a5ef-6379163eaf57',
#   'AMERICAN CHAMBER OF PANAMA'): 'american chamber of panama',
#  ('1208dc89-75d3-5e57-98b4-35a49c113641',
#   'DOMESTIC FUEL SOLUTIONS GROUP'): 'domestic fuel solutions',
#  ('120c9586-3bb5-525f-9c6d-567e5da0d234',
#   'UST PUBLIC AFFAIRS INC'): 'ust public affairs',
#  ('121dec0c-983e-5d49-bda3-c3063ce489bc',
#   'IMMUNOPRECISE ANTIBODIES LTD'): 'immunoprecise antibodies',
#  ('1221b913-cb42-52b4-9dd1-6af4e2b0f62a', 'LONE STAR RAIL'): 'lone star rail',
#  ('12316571-6c41-539f-be99-5769087af7de',
#   'INTERNATIONAL MUSEUM OF WOMEN'): 'international museum of women',
#  ('123e0abe-76e8-5efc-8fe4-4584a8ed8493',
#   'FIELDSTONE FAMILY HOMES'): 'fieldstone family homes',
#  ('1251ec60-6344-5445-81f6-9bc90ef7b11c', 'ERINMEDIA LLC'): 'erinmedia',
#  ('12670281-ebdc-5f28-997b-ff867f5c32c2', 'CYTOSPAR LLC'): 'cytospar',
#  ('127a25de-15f7-516c-9285-06b39154e133',
#   'KACHEMAK RESEARCH DEVELOPMENT, INC.'): 'kachemak research development',
#  ('1280772e-b0d0-5245-b080-0c2db54b6fa7',
#   'CLEAN EMISSION TECHNOLOGIES, INC.'): 'clean emission technologies',
#  ('12b2adde-0bb2-5c14-9c91-aa5fba86fce7', 'EWR'): 'ewr',
#  ('12b48e6e-3957-500d-bfbe-3bc471893ffc',
#   'GUILD ASSOCIATES INC'): 'guild associates',
#  ('12bb39db-d047-5e96-b06f-effa8bec2a97',
#   'VITAS HEALTHCARE CORPORATION'): 'vitas healthcare',
#  ('12ce1d10-4c9d-5d57-b5cb-cdcf58413e20',
#   'GOOGLE, INC. ON BEHALF OF X'): 'google on behalf of x',
#  ('12e8ffa5-c46a-5d68-a60a-f470fc0a2417', 'CBS CORPORATION'): 'cbs',
#  ('12edfa46-b985-5213-97b2-68ec876b2c3f',
#   'AMERICAN MUNICIPAL POWER'): 'american municipal power',
#  ('12ff66e5-0181-518e-b36b-381dc16fe6b0',
#   'LPTV BROADCASTERS ASSOCIATION'): 'lptv broadcasters association',
#  ('131e3a12-cea2-5253-8149-45162538c57d', 'VISBY MEDICAL'): 'visby medical',
#  ('1322aa1c-df76-5e79-a6da-1113389d011c', 'JFY NETWORKS'): 'jfy networks',
#  ('1324834a-7917-5c9a-91ab-d11ceae7ca93', 'BOAT US'): 'boat us',
#  ('13386e12-aae8-5adc-bbe8-6b0661173deb', 'GV SPRING HILL'): 'gv spring hill',
#  ('13417768-344f-5e4e-a659-105b02556d9f',
#   'LIVINGSTON GROUP LLC ON BEHALF OF BOHANAN HUSTON INC'): 'livingston on behalf of bohanan huston',
#  ('13495ab0-f4a5-5609-951b-f29faba1f79b',
#   'INTERNET DOMAIN NAME REGISTRARS COALITION'): 'internet domain name registrars coalition',
#  ('135b3107-e7ac-5e02-8149-185ed6717638',
#   'MEMORIAL HEALTH UNIV MEDICAL CENTER'): 'memorial health univ medical center',
#  ('1365b3ea-d1ac-5065-b0ea-d4b789625b5d',
#   'WEDONTHAVETIME AB'): 'wedonthavetime ab',
#  ('136d9527-fdeb-5f63-abb7-e8809eb7dc73',
#   'KORONIS PHARMACEUTICALS'): 'koronis pharmaceuticals',
#  ('1372cd03-fd44-5bf0-a075-e7f32c171ce3',
#   'STANLEY M SELIGSON PROPERTIES'): 'stanley m seligson properties',
#  ('137cdaf2-242e-5a85-8788-7f376b0fc0c8', 'SYSCO CORP'): 'sysco',
#  ('137ede77-dc0d-5a28-b12a-21d438f07fd5', 'THE CORMAC GROUP'): 'cormac',
#  ('139fa2df-8640-5d94-8e22-ad786fda11be',
#   'SPI SPIRITS (CYPRUS) LTD'): 'spi spirits (cyprus)',
#  ('13a9ce5b-a843-5509-97c0-9b62032663b9',
#   'MINIMILL 201 COALITION (LONG PRODUCTS)'): 'minimill 201 coalition (long products)',
#  ('13ea77fd-aea2-5bbb-b2fd-13a93fdaf580',
#   'CHISHOLM BROADBAND'): 'chisholm broadband',
#  ('13b42233-3978-5b86-8663-39cf75373eed', 'STAUBACH INC'): 'staubach',
#  ('13be09b5-6ecd-5ab7-8f7f-d1bd8230122b',
#   'LAKE AREA TECHNICAL INSTITUTE'): 'lake area technical institute',
#  ('13d62fa2-fd3d-5576-a8f2-7ef8e28a7e67',
#   'FIBROTEX USA, INC.'): 'fibrotex usa',
#  ('13dd6b27-8f8f-57ac-891a-502918a6a306',
#   'ASHFORD HOSPITALITY TRUST, INC.-ASHFORD, INC.'): 'ashford hospitality trust inc-ashford',
#  ('13e2808e-0f05-5e41-8014-79004a1e823d',
#   'THERMO FISHER SCIENTIFIC'): 'thermo fisher scientific',
#  ('13e2e603-c4a1-5f96-a4f5-919dc7b9b31e', 'RAZOR USA LLC'): 'razor usa',
#  ('13ee7b90-63a6-5c03-8f3f-4f963fec5cc2', 'NOVALENT'): 'novalent',
#  ('13fd3b77-16de-5f95-813f-0c2862d6b7ca',
#   'FARMERS FOR CLEAN AIR AND WATER'): 'farmers for clean air water',
#  ('1407eca3-8386-5cd0-aaab-8ab4ab80dcae',
#   'US FUEL CELL COUNCIL'): 'us fuel cell council',
#  ('141183f9-512e-5acf-a37b-2ceb296fd1ad',
#   'CRESTAR FINANCIAL CORP'): 'crestar financial',
#  ('141927f8-168f-5bc7-8207-a59f83d9cfb4',
#   'MIDDLE GEORGIA COLLEGE'): 'middle georgia college',
#  ('1433b7d1-2af2-539f-af4c-6a67ac3b34e7',
#   'POLY MET MINING, INC.'): 'poly met mining',
#  ('14344b77-627f-5d34-b693-9eb2929599bb',
#   'THAI GARMENT MANUFACTURERS ASSN'): 'thai garment manufacturers assn',
#  ('1443460f-ffc7-5ad1-b819-01a96015374b',
#   'POLICY DEVELOPMENT GROUP'): 'policy development',
#  ('1452c147-4494-5079-a0a0-ebe02265b0a6', 'VAPOTHERM INC'): 'vapotherm',
#  ('146f287a-5e60-524e-8b8b-579cf7b83d19',
#   'BROWARD METROPOLITAN PLANNING ORGANIZATION'): 'broward metropolitan planning organization',
#  ('1483ede6-0f48-5956-8a1e-c2883f3738d7',
#   'COALITION FOR A COMPETITIVE PHARMACEUTICAL MARKET'): 'coalition for a competitive pharmaceutical market',
#  ('1484f01d-c22f-5921-8064-6f733090c26c',
#   'SAMARITAN FOUNDATION INC.'): 'samaritan foundation',
#  ('14a4dc0d-93e0-5dca-a184-b16b03593274',
#   'TURKISH COALITION OF AMERICA'): 'turkish coalition of america',
#  ('14b3050d-ae29-52ee-ad10-8f6f7424dfc0', 'MOBILVOX INC'): 'mobilvox',
#  ('14c6600d-5d86-5875-9c8e-f3e1d5e71d4b', 'CHEYTAC ASSOC'): 'cheytac assoc',
#  ('14d3a9e6-acca-54a6-bea2-854e0c0615e7', 'ATLAS HOLDINGS'): 'atlas holdings',
#  ('14f1eb46-8301-505b-85ac-26d07546119b',
#   'COMPETE AMERICA'): 'compete america',
#  ('14f91848-04b7-501d-b22f-14da5076e5a4',
#   'FAMILY CONNECTION OF SOUTH CAROLINA'): 'family connection of south carolina',
#  ('15010ea1-967f-58ea-a935-665588ec3afa',
#   'UNITED WATER SERVICES'): 'united water services',
#  ('1505006a-3d57-557e-83cd-e18233b135fb', 'COOS COUNTY'): 'coos county',
#  ('15050273-034e-521a-82cd-447082e469f1',
#   'MONMOUTH COUNTY'): 'monmouth county',
#  ('15246aad-0e12-5294-8381-6b6b171a9335',
# ...
#  ('24fcfb6f-5972-5e52-bdf3-2d16ba0aa474',
#   'SOLVAY AMERICA, INC.'): 'solvay america',
#  ('25037752-639d-57ff-ae7b-f07d86a411ed',
#   'COMMUNITY FUNDS, INC. DBA THE NEW YORK COMMUNITY TRUST'): 'community funds dba new york community trust',
#  ('250c019f-a03a-581a-8944-f2bd3c447aad', 'FLOURISH'): 'flourish',
#  ('250c788a-f482-5318-9a47-bef5a6a69afb', 'MATCHRX'): 'matchrx',
#  ('2524fdb5-7af6-505e-bcfc-feb18b118cf1', 'OPTI-HARVEST'): 'opti-harvest',
#  ('252d2d21-8a32-5cac-8b7f-409e1102b8cc',
#   'MAGIC JOHNSON FOUNDATION'): 'magic johnson foundation',
#  ('2530be5c-1bfc-596f-92f7-2546d005fe80',
#   'CRESTWOOD MIDSTREAM PARTNERS LP'): 'crestwood midstream',
#  ('253c9c03-c55e-5f16-a394-bb4acdb8c07e',
#   'DIBC HOLDINGS, INC.'): 'dibc holdings',
#  ('253dd304-804e-5316-aa16-cb66a803e3bf',
#   'SOUTHWESTERN UNIV'): 'southwestern univ',
#  ('2544746a-65cb-509e-992a-e590d0bc46f3',
#   'CHERRY BANCROFT SUMMIT COORIDOR COALITION'): 'cherry bancroft summit cooridor coalition',
#  ('2566b4da-bb1f-5468-8866-cf7571a15eb0', 'MATTERMOST, INC.'): 'mattermost',
#  ('257a5e3d-e548-5d81-b0bf-8bc97b0b6ecb',
#   'COUNCIL FOR THE ACCREDITATION OF EDUCATOR PREPARATION'): 'council for accreditation of educator preparation',
#  ('257d7a79-442a-5b3d-a036-2e3cbdfa68d7',
#   'AIR CONDITIONING, HEATING AND REFRIGERATION INSTITUTE (AHRI)'): 'air conditioning heating refrigeration institute (ahri)',
#  ('257f4ab3-02fe-5615-84ce-bbe1c25d24f6', 'CHAPMAN HOUSE'): 'chapman house',
#  ('257fd66c-0b5c-5d4c-b9da-0f55613739e2',
#   'LANGSTON IN THE 21ST CENTURY FOUNDATION'): 'langston in 21st century foundation',
#  ('2580aaf3-e1d7-5ae2-bfa0-4980b527496f', 'GOVEVOLVE'): 'govevolve',
#  ('258a1642-5e66-5e51-8e14-43d8352a31c3',
#   'ASSOCIATION OF INTERNATIONAL AUTOMOBILE MANUFACTURERS INC'): 'association of international automobile manufacturers',
#  ('2592168f-b8d5-5b40-a25d-466d920f0dda',
#   'J2 TECHNOLOGIES, INC.'): 'j2 technologies',
#  ('2599c86b-63ab-58a5-94b5-a6c3491b7d4e',
#   'BOROUGH OF STATE COLLEGE'): 'borough of state college',
#  ('25a59b79-6bc0-5f95-b9fa-d773f20ec68a',
#   'TOKYO KIKAI SEISAKUSHO, LTD.'): 'tokyo kikai seisakusho',
#  ('25b1f94c-5fc0-5652-bd8d-697b9f859f69',
#   'HYPERLOOP TRANSPORTATION TECHNOLOGIES'): 'hyperloop transportation technologies',
#  ('25bcf791-f22c-508f-b856-5d3d92fc605d',
#   'DON SCHUMACHER RACING'): 'don schumacher racing',
#  ('25c3261a-c41d-500a-85d6-4713bd75b743',
#   'COALITION OF HOPE FOUNDATION'): 'coalition of hope foundation',
#  ('25cd47d0-90e7-5b49-aa1d-38477cb400e4',
#   'TURNAROUND FOR CHILDREN, INC.'): 'turnaround for children',
#  ('25da9292-4777-5fa7-a4a7-086bb949f83f',
#   'CITY OF JASPER AL'): 'city of jasper al',
#  ('25dab15a-350b-5a6b-bb03-96f3b6480006',
#   'MUNICIPAL TRANSIT OPERATORS COALITION'): 'municipal transit operators coalition',
#  ('25ebb9c0-5eca-5551-9f21-bcb27df0aa70',
#   'RAD POWER BIKES'): 'rad power bikes',
#  ('261465a1-ae2e-57d7-84db-3178da9d7248',
#   'NASSAU-PARADISE ISLAND PROMOTION BOARD - KERZNER INTERNATIONAL RESORTS INC'): 'nassau-paradise island promotion board - kerzner international resorts',
#  ('26171c2f-3d19-5574-948e-00e07fc443fd',
#   'MISSILE DEFENSE ADVOCACY ALLIANCE, INC.'): 'missile defense advocacy alliance',
#  ('261ff450-36cc-5745-99b7-5d39dbeb13f3', '633-4S RANCH LTD'): '633-4s ranch',
#  ('2636fb2e-28de-5ae2-a18b-453706ea65cb',
#   'AMBERWAVE SYSTEMS CORPORATION'): 'amberwave systems',
#  ('2638fa66-d072-50c6-bdb9-03cc568f2537', 'EMMONAK CORP'): 'emmonak',
#  ('2645aff6-f164-5300-8745-d2035105733b',
#   'NATIONAL RESIDENT MATCHING PROGRAM'): 'national resident matching program',
#  ('264aeb75-f044-5a55-9f7a-9df1339b199f', 'QUIKTRIP CORPORATION'): 'quiktrip',
#  ('264d633b-05e1-5546-aee1-fc5d5f865d3a', 'ARTIS, LLC'): 'artis',
#  ('2657bb58-03a5-59b1-9c3b-e29d2a687a20',
#   'PACE, LLP ON BEHALF OF JAGUAR LAND ROVER NORTH AMERICA, LLC'): 'pace llp on behalf of jaguar land rover north america',
#  ('26693c19-eba2-5505-b350-97c8995d5c65',
#   'CITY OF HARKER HEIGHTS, TEXAS'): 'city of harker heights texas',
#  ('266c2ed0-7151-5541-bc9e-bb284ae793cf',
#   'EQUIVA SERVICES'): 'equiva services',
#  ('2678d9ed-8656-565b-891c-b1a6092f3f34',
#   'WESTERN UNITED DAIRYMEN'): 'western united dairymen',
#  ('26a1557c-2612-5bbd-b07f-a2d403a6ebc7',
#   'CASS COUNTY, INDIANA BOARD OF COMMISSIONERS'): 'cass county indiana board of commissioners',
#  ('26a76d71-f56d-50c5-a1cb-11ba7790e154',
#   'CITY OF DIAMOND BAR, CA'): 'city of diamond bar ca',
#  ('26b7d694-6717-537f-82bf-b0fc3046263c', 'ELMS COLLEGE'): 'elms college',
#  ('26b7d70a-6268-59ff-bd2d-420891ef8504',
#   'VARI SALES CORPORATION'): 'vari sales',
#  ('26c7e372-387e-5048-89ba-677f8abf9fc3', 'MECHANOLOGY'): 'mechanology',
#  ('26c7ef72-8a7e-5aaf-9acd-584fb9d579ee',
#   "AMERICA'S VOICE"): "america's voice",
#  ('26d0118a-e4e8-5c90-8fba-76b844e2f21f',
#   'AMERICAN BOARD OF EXAMINERS CLINICAL SOCIAL WORK'): 'american board of examiners clinical social work',
#  ('26e65587-f49d-5c22-907e-a01136d8d75d',
#   'MARICOPA ASSOCIATION OF GOVERNMENTS'): 'maricopa association of governments',
#  ('26ec0b0e-1e5e-591e-9136-1f44e9ab9e2a', 'SCEYE INC.'): 'sceye',
#  ('26f119b5-848e-5f78-98b7-cf1a3bcbc342', 'TRILEGACY GROUP'): 'trilegacy',
#  ('26fdb4c1-55ef-5034-b964-c96c6bcdc81c',
#   'ARMSTRONG ATLANTIC STATE UNIVERSITY'): 'armstrong atlantic state university',
#  ('270bea79-d495-5da9-9459-7705db476b67',
#   'ALLIANCE ONE INTERNATIONAL, INC.'): 'alliance one international',
#  ('2711cc5e-d7f0-5141-90cd-c042740dbd37',
#   'MARTINEZ & CURTIS'): 'martinez curtis',
#  ('2718e80a-ce9b-53d9-8dfa-16b30e1132f3', 'BRIGHTVIEW'): 'brightview',
#  ('271e5f9c-981e-59ab-ad7a-065822e6eeae',
#   'NORRIS ELECTRO OPTICAL SYSTEMS CORP'): 'norris electro optical systems',
#  ('271fda17-d4ce-566d-ba1e-0c563f82584f',
#   'SECOND CHANCE BODY ARMOR'): 'second chance body armor',
#  ('2738b3ef-79db-5722-becd-99c3dffc3347', 'SAN-I-PAK'): 'san-i-pak',
#  ('274cfbe2-cc58-506b-864d-bba8cef9009d',
#   'WESTERN ENVIRONMENTAL LAW CENTER'): 'western environmental law center',
#  ('2750d03f-5678-50dc-a202-ee9aba53c533',
#   'INFO TECH SOLUTIONS FOR BUSINESS'): 'info tech solutions for business',
#  ('27632fec-0f07-5a8b-b0a2-e11661f16232', 'ONEBEACON CORP'): 'onebeacon',
#  ('27654bbe-3226-5b57-89f7-4c6c78c9ed62',
#   'RECOVERMAT TECHNOLOGIES LLC'): 'recovermat technologies',
#  ('27683493-89fa-56ba-9c20-75d24b05bd8e', 'MMM HEALTHCARE'): 'mmm healthcare',
#  ('278d56a2-3f79-5892-96bc-7d57cb304848',
#   'ALLIANCE OF U.S. STARTUPS AND INVENTORS FOR JOBS (USIJ)'): 'alliance of us startups inventors for jobs (usij)',
#  ('2790ba56-732a-5fb3-be74-70c9bb555af6',
#   'COMMUNICATING FOR AGRICULTURE'): 'communicating for agriculture',
#  ('279fa2b7-6e18-5b91-92de-275edcdff2fe',
#   'VILLAGE OF FREEPORT'): 'village of freeport',
#  ('27a00493-1a8b-5a16-837a-da1b1fa8d1fa',
#   'COMMUNITY HEALTH ASSOCIATION OF SPOKANE'): 'community health association of spokane',
#  ('27a7f498-bb36-59cf-b2a1-2d3a0d6cc383',
#   'VIROPHARMA INCORPORATED'): 'viropharma incorporated',
#  ('27ad657a-d0e1-54db-8312-8b75d574b6b8',
#   'WIN AMERICA CAMPAIGN'): 'win america campaign',
#  ('27ae031f-785c-5383-8792-d85e36de363b',
#   'BUSINESS COUNCIL OF ALABAMA'): 'business council of alabama',
#  ('27b978d4-d91e-5e4c-ae5d-d181026a9d81',
#   'LETS GO BOYS AND GIRLS'): 'lets go boys girls',
#  ('27bde389-33a0-5b21-a64e-19cab6f9c796',
#   'MESCALERO APACHE TRIBE'): 'mescalero apache tribe',
#  ('27c0c8e6-44b6-5aa2-b193-aafaebdcdf60', 'ZTEK CORP'): 'ztek',
#  ('27c2b1f8-e737-527f-a0dd-ba6bb0e03c46',
#   'SLINGSHOT AEROSPACE'): 'slingshot aerospace',
#  ('27cda6ac-dee3-569f-a0d6-62c48554d36e',
#   'MICHIGAN LEAGUE FOR HUMAN SERVICES'): 'michigan league for human services',
#  ('27d09b58-6bae-52a2-be0b-c3d347992818', 'NO LABELS'): 'no labels',
#  ('27d13b14-85d8-5d25-8e45-d98490a4f918',
#   'COALITION OF EXCLUSIVE AGENT ASSNS'): 'coalition of exclusive agent assns',
#  ('27defc13-30c3-58ca-9477-94a0bdadf6d1',
#   'ALLIANCE OF HEALTH CARE SHARING MINISTRIES'): 'alliance of health care sharing ministries',
#  ('27f7e908-d399-506d-af57-b39a8ed12223',
#   'HARVARD DESIGN & MAPPING'): 'harvard design mapping',
#  ('280e1417-1911-5cd9-9df1-25e0675bd905',
#   'AFTER-SCHOOL ALL-STARS'): 'after-school all-stars',
#  ('281fa543-d29e-5def-9d0a-63793e267acd',
#   'THE ALLIANCE FOR STRONG FAMILIES AND COMMUNITIES'): 'alliance for strong families communities',
#  ('282a8bf0-053c-50a6-9a87-60211e3ed3ef',
#   'CITY OF WESTLAKE VILLAGE'): 'city of westlake village',
#  ('283164d3-b532-5248-80ce-374ca239ae48',
#   'NEW AFFINITY CONCEPTS CORP.'): 'new affinity concepts',
#  ('2835421c-df7c-54eb-bdfe-9acefd479a22',
#   'VILLAGE OF MONTPELIER, OHIO'): 'village of montpelier ohio',
#  ('28373a04-d34f-5590-b68c-31535804315c',
#   'FINCANTIERI MARINE SYSTEMS NORTH AMERICA INC (PREVIOUSLY FDGM INC )'): 'fincantieri marine systems north america (previously fdgm )',
#  ('2852749e-46a2-564f-909d-70f04c231419',
#   'ASBURY AUTOMOTIVE GROUP'): 'asbury automotive',
#  ('2873cf9c-c161-504c-a015-430e8e8f6bf5',
#   'CITY OF PROVIDENCE'): 'city of providence',
#  ('287cd65d-aed2-5af7-ad6a-abc6625bfb3a',
#   'APPLETON PAPERS INC'): 'appleton papers',
#  ('287d4db4-801d-5ae3-8611-be143e84677b', 'ACCUTHERA INC'): 'accuthera',
#  ('287fef2b-b867-51d7-9c77-ec9185678329',
#   'DALLAS SPORTS COMMISSION'): 'dallas sports commission',
#  ('28805c43-4722-5b76-9803-aa95935dcf98', 'DANAHER CORPORATION'): 'danaher',
#  ('288a6caa-0c4a-58cf-a133-be4e13c3b726', 'NAKASEC'): 'nakasec',
#  ('288fbd46-5157-5070-aa33-b95f005865bd',
#   'INTERCONTINENTAL HOTELS GROUP'): 'intercontinental hotels',
#  ('289142d3-507f-58e5-8399-9c12a3d41a04',
#   'INSTITUTE FOR AGING RESEARCH'): 'institute for aging research',
#  ('289ceeae-60c9-5c51-bc6c-eeaaeac59004', 'NETAPP'): 'netapp',
#  ('28b918b0-0c37-533d-99f5-7cd29c843cf5',
#   'SOUTHEASTHEALTH'): 'southeasthealth',
#  ('28bc2b95-002a-5a2f-9ec1-e446a9e9e8d4', 'TRICORBRAUN'): 'tricorbraun',
#  ('28c1bef3-385c-5756-bc6e-31ff9da387c3',
#   'PRAXIS PRECISION MEDICINES'): 'praxis precision medicines',
#  ('28def0d1-ac2f-5e01-b0b2-932dddd72c09',
#   'MR. WALID HABBOO AND FAMILY'): 'mr walid habboo family',
#  ('28e1f7c0-2257-50f7-92ed-00edc87e3f93', 'KAISER-HILL CO'): 'kaiser-hill',
#  ('28f353a0-3a21-55f1-84d5-b5f8919a5d98',
#   'STOCK ISLAND LOBSTER COMPANY'): 'stock island lobster',
#  ('290b6798-77a6-5455-85ac-a52c489e1ad3',
#   'EASTERN BAND OF CHEROKEE INDIANS'): 'eastern band of cherokee indians',
#  ('290ea4c6-b5c0-5283-9e8f-832e3dd88646',
#   'HEALTH CARE ALLIANCE FOR PATIENT SAFETY'): 'health care alliance for patient safety',
#  ('2921338d-8862-54a2-a1f2-b9c59d53846e',
#   'BARNES-AASTAD ASSOCIATION'): 'barnes-aastad association',
#  ('293b84a2-2f66-555e-b16a-ed4ebe059e76',
#   'PORT OF PORTLAND'): 'port of portland',
#  ('294f0c45-d4ac-5366-bd52-37040ef482b9',
#   'WAYNE COUNTY AIRPORT AUTHORITY'): 'wayne county airport authority',
#  ('2957e205-09ad-5bda-ae50-60d1ac54f2d0',
#   'GREAT-WEST LIFE & ANNUITY INSURANCE CO'): 'great-west life annuity insurance',
#  ('295a030a-d3e7-5476-9c60-4d4d294d7bd4',
#   'TEXAS TECH UNIV HEALTH SCIENCES CTR'): 'texas tech univ health sciences ctr',
#  ('2960fe02-548a-5b60-b9d9-67b7a32b51be', 'MACHAL INC'): 'machal',
#  ('29698a60-2b32-55e3-93a5-b32d974f2fe9',
#   'XELAS SYSTEMS ENGINEERING, LLC'): 'xelas systems engineering',
#  ('296fa555-f976-54fc-aa0c-4c841ae2e3bc', 'SIA'): 'sia',
#  ('29a9cff9-c3c5-5d63-bf11-c8a95ada123a',
#   'NEWMARKET SCHOOL DISTRICT'): 'newmarket school district',
#  ('29b7a0f7-fd36-5e2a-8efc-b6960c720865',
#   'SEARCH LIGHT MINERALS CORPORATION'): 'search light minerals',
#  ('29b8c5b0-1d38-5b4a-b25d-d8fc33dfdd72', 'ARBOR VITA CORP'): 'arbor vita',
#  ('29bf8320-f146-5abc-9329-2aac4b4ecb10', 'INVIZEON'): 'invizeon',
#  ('29c97f7e-0a91-5a96-8562-b94c0c1e568e',
#   'MONTANA & ASSOCIATES, LLC ON BEHALF OF OMAHA TRIBE OF NEBRASKA/CROW CREEK TRIBE'): 'montana associates on behalf of omaha tribe of nebraska/crow creek tribe',
#  ('29eeafbf-48d4-561c-997d-3afc2c5b937e',
#   'WEST COAST WATERFRONT COALITION'): 'west coast waterfront coalition',
#  ('29fec885-7b26-5a56-bd21-fa6e3855fb64',
#   'PROJECT FOR OPPORTUNITY AND SAFETY, INC.'): 'project for opportunity safety',
#  ('2a04b983-d420-5efa-b502-2fffe2037ac0',
#   'COACH AMERICA HOLDINGS, INC.'): 'coach america holdings',
#  ('2a0deb14-2665-564b-91da-25ba87759d13',
#   'UPPER MATTAPONI INDIAN TRIBE'): 'upper mattaponi indian tribe',
#  ('2a156b46-0d56-570c-84f5-2b96bdfc4a8c', 'EAGLE AIR MED'): 'eagle air med',
#  ('2a60273b-454f-5dc3-bf70-59c11fbf3cd0', 'LDW'): 'ldw',
#  ('2a36f3ef-c8d2-5bae-8382-0aabac5edc8b',
#   'INDIANA STATEWIDE ASSN OF RURAL ELECTRIC COOPS'): 'indiana statewide assn of rural electric coops',
#  ('2a3bf44f-0bb4-5cfe-9454-0c8c47eaaa43', 'FRANCO HERNAN'): 'franco hernan',
#  ('2a40dd72-68e2-56af-a596-2c5135be0a48',
#   'RESOURCES INVESTMENT'): 'resources investment',
#  ('2a4a6f0c-18f6-53e3-b45b-8c47071366d8',
#   'BRAMBLE BERRY INC.'): 'bramble berry',
#  ('2a57b523-1725-56ed-a5ec-30c74f38ec10',
#   'HALIFAX INTL AIRPORT'): 'halifax intl airport',
#  ('2a596cbf-205a-5cdb-95cb-26c888cb7af9',
#   'HEADS UP: A UNIVERSITY NEIGHBORHOOD INITIATIVE'): 'heads up: a university neighborhood initiative',
#  ('2a5dd744-0490-5255-861b-af34999d40cf',
#   'PORT OF KENNEWICK'): 'port of kennewick',
#  ('2a632d3e-b2a1-5d04-acf7-87482a987d9e',
#   'KAWEAH DELTA HOSPITAL FOUNDATION'): 'kaweah delta hospital foundation',
#  ('2a6d3978-1701-5341-ac41-5ee9807d29f6',
#   'AKERMAN SENTERFITT (ON BEHALF OF SENSIS CORPORATION)'): 'akerman senterfitt (on behalf of sensis corporation)',
#  ('2a75cd37-94ca-5ca3-b706-e810a9fdb1df', 'HART-CULP INTL'): 'hart-culp intl',
#  ('2a7e1538-cd18-5825-bb7f-3f9b475a60d6',
#   'NEW ORLEANS FEDERAL ALLIANCE (NOFA)'): 'new orleans federal alliance (nofa)',
#  ('2a9bbf8d-6914-5aaf-a503-1de15dd0a274',
#   'CROWDPULSE LLC DBA TORCHLIGHT IA (FKA CROWDPULSE LLC)'): 'crowdpulse dba torchlight ia (fka crowdpulse llc)',
#  ('2aba401e-a5d1-5c7b-850f-28eb29283b45',
#   'GLOBAL COMPETITIVENESS COALITION 2000'): 'global competitiveness coalition 2000',
#  ('2ac157d4-f573-51bb-9a91-11b9d9abb74f',
#   'TRANSYLVANIA UNIVERSITY'): 'transylvania university',
#  ('2ac32ac5-b14f-5c3e-93f3-a332860e8213',
#   'ALASKA PEAT COMPANY'): 'alaska peat',
#  ('2aca4efe-27a0-5819-92bf-3acf3c52d77b', 'INSIGHT'): 'insight',
#  ('2acd8dde-39da-5b1a-8bd0-af92764fe3f1',
#   'GENESEE COMMUNITY COLLEGE'): 'genesee community college',
#  ('2acfc4af-598b-52a2-8d02-dc048452ced5',
#   'PALMETTO HEALTH FOUNDATION'): 'palmetto health foundation',
#  ('2adf42f6-b405-5fb9-9ae9-4108d1efa98b', 'TARGET CORPORATION'): 'target',
#  ('2ae3ae64-ed38-5e60-b788-8b75648dff6a',
#   'NATIONAL FLEA MARKET ASSOCIATION'): 'national flea market association',
#  ('2af37c0a-9f87-5eb8-9683-75d247458bac',
#   'GATEWAY CLIPPER FLEET'): 'gateway clipper fleet',
#  ('2b0a7fd7-404c-55cb-81d6-51dae3b3de9e',
#   'RESEARCH PLANNING'): 'research planning',
#  ('2b12f0ab-9023-5a68-be1c-f39451a806d8',
#   'NATIONAL VOTE AT HOME COALITION'): 'national vote at home coalition',
#  ('2b16e18a-3ded-56b5-a784-5769ceb2e3c9',
#   'EAST WHITELAND TOWNSHIP'): 'east whiteland township',
#  ('2b20769a-29b5-52b7-a072-b5bc2f4a34bc',
#   'STATE OF WYOMING'): 'state of wyoming',
#  ('2b38a3f9-0d94-526f-9a09-44844d13eda6', 'DELAMERICAN INC'): 'delamerican',
#  ('2b3d73ad-b186-5f35-94e1-f80079f5b9e9',
#   'FOUNDATION FOR ENVIRONMENTAL AND ECONOMIC PROGRESS'): 'foundation for environmental economic progress',
#  ('2b417b5b-a95b-52a4-89f1-a733955b3dd2',
#   'CARDINAL GLASS INDUSTRIES'): 'cardinal glass industries',
#  ('2b5076bd-8278-5a0e-aa74-95f549261afb',
#   'WALTON INTERNATIONAL GROUP (USA), INC.'): 'walton international (usa)',
#  ('2b5d1d9d-96f5-5f37-9bcf-1030147c3344',
#   'TITLE IV-A COALITION'): 'title iv-a coalition',
#  ('2b5ffab4-5553-5607-8c2e-dea7631f5009',
#   'ATHABASCA UNIVERSITY'): 'athabasca university',
#  ('2b64ea72-cb43-5fb5-9133-3b4bc74dc3b9',
#   'EXELIS INC. (FORMERLY ITT CORPORATION)'): 'exelis (formerly itt corporation)',
#  ('2b67d559-fe5c-57d3-b692-f536f0ed65d3',
#   'TRANS WORLD TECHNOLOGIES'): 'trans world technologies',
#  ('2b78d63b-72f5-549d-aa4e-ce46b0b33786',
#   'ENGINEERING SOFTWARE RESEARCH AND DEVELOPMENT'): 'engineering software research development',
#  ('2b85991b-663e-5d72-9e3b-7e44407dbdc7',
#   "WOMAN'S HOSPITAL"): "woman's hospital",
#  ('2b866ec7-8f5e-5c1e-8e24-a7bd709e8059', 'FASTERCURES'): 'fastercures',
#  ...}

# %% [markdown]
# ## Exporting matching results

# %%
fuzzy_matching_filtered.to_csv("adv_matching_filtered.csv",index=False)
fuzzy_matching_client.to_csv("client_matching.csv",index=False)

# %% [markdown]
# ## Import manual matching

# %%
matching_final = pd.read_excel("matching_final.xlsx")
matching_final = duckdb.query("SELECT * FROM matching_final where keep_flag = 'Y' or tsr_score = 100").to_df()
matching_final
# Out:
#          ID                             Name  registrant_id  \
# 0       347                              PPL          31086
# 1       145                            Xerox          42001
# 2       502                            Scana          34466
# 3        71                            Sysco      401103671
# 4       459                           Timken          38153
# ..      ...                              ...            ...
# 316  222539                    Rose Law Firm      401106170
# 317  329067  Vorys, Sater, Seymour and Pease          40236
# 318   26640     Cadwalader Wickersham & Taft           7645
# 319   41453       University of Texas Austin       40013107
# 320       2                       ExxonMobil          14017
#
#                                    match   tsr_score  ratio_score keep_flag
# 0                        PPL CORPORATION  100.000000    33.333333      None
# 1                      XEROX CORPORATION  100.000000    45.454545      None
# 2                      SCANA CORPORATION  100.000000    45.454545      None
# 3                      SYSCO CORPORATION  100.000000    45.454545      None
# 4                     THE TIMKEN COMPANY  100.000000    50.000000      None
# ..                                   ...         ...          ...       ...
# 316               THE ROSS LAW FIRM, LLC   92.307692    68.571429         Y
# 317  VORYS, SATER, SEYMOUR AND PEASE LLP   92.592593    93.939394         Y
# 318    CADWALADER, WICKERSHAM & TAFT LLP   92.857143    91.803279         Y
# 319    THE UNIVERSITY OF TEXAS AT AUSTIN   94.545455    88.135593         Y
# 320                     EXXON MOBIL CORP   95.238095    76.923077         Y
#
# [321 rows x 7 columns]

# %%
matching_final_clients = pd.read_csv("client_matching.csv")
matching_final_clients = duckdb.query("SELECT *FROM matching_final_clients where match is not null and tsr_score >95 order by tsr_score").to_df()
matching_final_clients
# Out:
#          id                            name  registrant_id  \
# 0         2                      ExxonMobil        14017.0
# 1     68095  The Estée Lauder Companies Inc            NaN
# 2    280284                     ObjectVideo            NaN
# 3     78575               NBCUniversal, LLC            NaN
# 4    423225     United Against Nuclear Iran            NaN
# ..      ...                             ...            ...
# 627  351432                         Carbyne            NaN
# 628  368170           Las Vegas Sands, Inc.            NaN
# 629  386927         Third Option Foundation            NaN
# 630  427139                  Viridi Parente    401105993.0
# 631  431426                Roivant Sciences            NaN
#
#                                match   tsr_score  ratio_score  \
# 0            EXXON MOBIL CORPORATION   95.238095    60.606061
# 1    THE ESTEE LAUDER COMPANIES, INC   95.454545    95.081967
# 2                       OBJECT VIDEO   95.652174    95.652174
# 3                      NBC UNIVERSAL   96.000000    80.000000
# 4      UNITED AGAINST A NUCLEAR IRAN   96.428571    96.428571
# ..                               ...         ...          ...
# 627                     CARBYNE INC.  100.000000    73.684211
# 628      LAS VEGAS SANDS CORPORATION  100.000000    75.000000
# 629          THIRD OPTION FOUNDATION  100.000000   100.000000
# 630             VIRIDI PARENTE, INC.  100.000000    82.352941
# 631           ROIVANT SCIENCES, INC.  100.000000    84.210526
#
#                                    lob_id
# 0    b9eeff59-e365-52d7-9cdf-b3a592d4e07a
# 1    904930e4-5d85-5b7d-a5db-256de8c51f53
# 2    d7728dfd-efff-5fba-829b-7762fb2a076e
# 3    25d3c718-e134-5a0e-a4c8-2782acd95219
# 4    cb54a625-cb27-5425-bada-af9ad60eb0c9
# ..                                    ...
# 627  f0288d93-e2fd-595a-b9d3-de8e78194176
# 628  5ba97d59-eb3c-5cdf-b958-34c108cbd8da
# 629  9edcff5e-c6e6-596f-bc8b-28122cd8788e
# 630  877ac008-05d3-5e55-9911-7b9d34cf022b
# 631  140f6ace-cf05-5f94-a311-125226f12fea
#
# [632 rows x 7 columns]

# %%
# SELECT reportu ktere maji pripojene littlesis ID (na registranta)
lobbying_reports_r = duckdb.query("SELECT mf.ID as littlesis_ID, re.* FROM lv_reports re inner join matching_final mf on re.registrant_id = mf.registrant_id where mf.ID is not null").to_df()
# pripojeni client_name z lv_clients (pres lob_id)
lobbying_reports_r = duckdb.query("SELECT l.*, c.client_name FROM lobbying_reports_r l left join lv_clients c on l.lob_id = c.lob_id ").to_df()

# %%
# SELECT reportu ktere maji pripojene littlesis ID (na clienta)
lobbying_reports_c = duckdb.query("SELECT mc.ID as littlesis_ID, re.* FROM lv_reports re left join matching_final_clients mc on re.lob_id = mc.lob_id where mc.ID is not null").to_df()
# pripojeni client_name z lv_clients (pres lob_id)
lobbying_reports_c = duckdb.query("SELECT l.*, c.client_name FROM lobbying_reports_c l left join lv_clients c on l.lob_id = c.lob_id ").to_df()

# %%
lobbying_reports_c
# Out:
#        littlesis_ID                           report_uuid  \
# 0                88  aabc5e5c-3d8e-4715-b4c3-40ffc15ab023
# 1                61  a23c1444-6c53-49ae-9fb4-ca2360e14851
# 2                61  50e14ae3-5eb1-48e4-8e01-efa993ea110d
# 3                61  11e001e5-7910-4be0-bce6-55e64f53853f
# 4                61  a6256a5c-f81a-408c-88fe-463bb683e0d4
# ...             ...                                   ...
# 47065        217668  a82d39e7-139e-4f32-87af-9184736a1c81
# 47066        217668  6780c687-9e4a-4cc2-8869-45c5fc1af5bb
# 47067        217668  908bb8f5-ebd7-4e60-a839-fdf62c722367
# 47068        217668  2af4c71a-9140-44a1-a8e5-00e8f0013eb7
# 47069        217668  ffa4f7f2-ef66-4e6e-8794-54d4cfb33389
#
#                                      lob_id  registrant_id  \
# 0      612ef4ed-22c1-5454-93a4-005b867899a4      401107502
# 1      3e54f727-549c-5ab3-9073-522a811520e7      401104716
# 2      3e54f727-549c-5ab3-9073-522a811520e7      401104716
# 3      3e54f727-549c-5ab3-9073-522a811520e7      401104716
# 4      3e54f727-549c-5ab3-9073-522a811520e7      401104716
# ...                                     ...            ...
# 47065  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 47066  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 47067  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 47068  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 47069  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
#
#                      registrant_name  filing_year filing_period_code   amount  \
# 0      MORAN GLOBAL STRATEGIES, INC.         2023                 Q2      NaN
# 1                KLEIN/JOHNSON GROUP         2021                 Q1  30000.0
# 2                KLEIN/JOHNSON GROUP         2021                 Q4  50000.0
# 3                KLEIN/JOHNSON GROUP         2021                 Q2  30000.0
# 4                KLEIN/JOHNSON GROUP         2021                 Q3  50000.0
# ...                              ...          ...                ...      ...
# 47065        BOUNDARY STONE PARTNERS         2022                 Q2  60000.0
# 47066        BOUNDARY STONE PARTNERS         2022                 Q3  60000.0
# 47067        BOUNDARY STONE PARTNERS         2023                 Q1      NaN
# 47068        BOUNDARY STONE PARTNERS         2022                 Q1      NaN
# 47069        BOUNDARY STONE PARTNERS         2022                 Q1      NaN
#
#        is_no_activity  is_self_filer  is_amendment  \
# 0               False          False         False
# 1               False           <NA>         False
# 2               False           <NA>         False
# 3               False           <NA>         False
# 4               False           <NA>         False
# ...               ...            ...           ...
# 47065           False          False         False
# 47066           False          False         False
# 47067            True          False         False
# 47068           False          False          True
# 47069           False          False         False
#
#                                               filing_url        client_name
# 0      https://lda.senate.gov/filings/public/filing/a...   GENERAL DYNAMICS
# 1      https://lda.senate.gov/filings/public/filing/a...  INTEL CORPORATION
# 2      https://lda.senate.gov/filings/public/filing/5...  INTEL CORPORATION
# 3      https://lda.senate.gov/filings/public/filing/1...  INTEL CORPORATION
# 4      https://lda.senate.gov/filings/public/filing/a...  INTEL CORPORATION
# ...                                                  ...                ...
# 47065  https://lda.senate.gov/filings/public/filing/a...       STRIPE, INC.
# 47066  https://lda.senate.gov/filings/public/filing/6...       STRIPE, INC.
# 47067  https://lda.senate.gov/filings/public/filing/9...       STRIPE, INC.
# 47068  https://lda.senate.gov/filings/public/filing/2...       STRIPE, INC.
# 47069  https://lda.senate.gov/filings/public/filing/f...       STRIPE, INC.
#
# [47070 rows x 13 columns]

# %%
#odmazání duplicit
lobbying_reports_c = duckdb.query("SELECT *FROM lobbying_reports_c where registrant_name != client_name ").to_df()
lobbying_reports_c["is_self_filer"] = False

# %%
def self_filer_fix(lobbying_reports):
    lobbying_reports["is_self_filer"] =lobbying_reports["is_self_filer"].fillna(False)

    #if client_name empty -> registrant_name
    lobbying_reports["client_name"] = lobbying_reports.apply(
        lambda row: row["registrant_name"] if pd.isna(row["client_name"]) else row["client_name"],
        axis=1
    )


    # if is_self_filer false or empty and registrant = client name set is_self_filer as True
    lobbying_reports["is_self_filer"] = lobbying_reports.apply(
        lambda row: True if (
            row["registrant_name"] == row["client_name"] and 
            (row["is_self_filer"] == False or pd.isna(row["is_self_filer"]))
        ) else row["is_self_filer"],
        axis=1
    )
    
    return lobbying_reports

# %%
lobbying_reports_r = self_filer_fix(lobbying_reports_r)
lobbying_reports_c = self_filer_fix(lobbying_reports_c)

# %%
# dataset s popisy problematky jednotlivých reportů
issue_codebook = pd.read_excel("issue_cdbk.xlsx")

merged = duckdb.query("SELECT * FROM lobbying_reports_r union all SELECT * FROM  lobbying_reports_c").to_df()

#pripojeni issue text k reportům + ciselnik k GIC
report_issues = duckdb.query("""
             SELECT i.report_uuid, i.general_issue_code, cd.description as description, i.bill_id_agg, i.issue_text
             FROM lv_issue_text i 
             left join issue_codebook cd on i.general_issue_code = cd.code
             inner join merged m on m.report_uuid = i.report_uuid
             """ ).to_df()

report_issues["bill_id_agg"]= report_issues["bill_id_agg"].str.replace(r'[{}]', '', regex=True) # odstranění {}

# %%
report_issues
# Out:
#                                  report_uuid general_issue_code  \
# 0       39fd84b3-5b25-4ba5-b5b6-dcc9d737470d                SMB
# 1       39fed6ab-97bf-408a-bbd3-fabd607bbe71                COM
# 2       39fed6ab-97bf-408a-bbd3-fabd607bbe71                CPI
# 3       39fed6ab-97bf-408a-bbd3-fabd607bbe71                CPT
# 4       39fed6ab-97bf-408a-bbd3-fabd607bbe71                DEF
# ...                                      ...                ...
# 234872  fff717c5-10d6-40e3-a8c9-92d45123d9ab                TAX
# 234873  fff717c5-10d6-40e3-a8c9-92d45123d9ab                EDU
# 234874  fff717c5-10d6-40e3-a8c9-92d45123d9ab                CPT
# 234875  fff717c5-10d6-40e3-a8c9-92d45123d9ab                IMM
# 234876  fffb4717-5daa-41b1-a794-6970a62800af                CIV
#
#                                  description bill_id_agg  \
# 0                             Small Business        None
# 1       Communications/Broadcasting/Radio/TV        None
# 2                          Computer Industry        None
# 3                 Copyright/Patent/Trademark        None
# 4                                    Defense        None
# ...                                      ...         ...
# 234872        Taxation/Internal Revenue Code        None
# 234873                             Education        None
# 234874            Copyright/Patent/Trademark        None
# 234875                           Immigration        None
# 234876          Civil Rights/Civil Liberties        None
#
#                                                issue_text
# 0                                              E-Commerce
# 1       S. 1260 - United States Innovation and Competi...
# 2       Government innovation; Innovation in the techn...
# 3                           Intellectual Property issues.
# 4       Issues related to government contracting; Nati...
# ...                                                   ...
# 234872                              Corporate tax reform.
# 234873                        Computer science education.
# 234874                                Patent legislation.
# 234875                   Immigration--high-skilled visas.
# 234876                                      Anti-Semitism
#
# [234877 rows x 5 columns]

# %% [markdown]
# ## Export final

# %%
#export
lobbying_reports_r.to_csv("neo_lobbying_reports.csv", index=False)
lobbying_reports_c.to_csv("neo_lobbying_clients.csv",index=False)
report_issues.to_csv("neo_report_issues.csv", index=False)

# %% [markdown]
# ## Testing

# %%
duckdb.query("SELECT * FROM lobbying_reports_r where is_self_filer = 'False' ").to_df()
# Out:
#        littlesis_ID                           report_uuid  \
# 0            326262  c4fcfc56-f96d-4690-82ca-c4b744d73c71
# 1            326262  4777ae2d-f4f0-4117-bb46-7d783edfc628
# 2            326262  47334776-1188-4991-b854-406d9c1140de
# 3            326262  b3eaf19d-fe3e-456e-9f9d-e7ab38b95b22
# 4            326262  5a1dd3f9-c987-4f14-a64f-7f770b908a18
# ...             ...                                   ...
# 66612         21559  ed9680fc-e81e-4aee-8b72-9348168bf891
# 66613         15859  f37d09cd-691c-4d6c-b000-3b65927bce65
# 66614         23624  a2f3e4c9-7afe-450f-8475-e0290a261999
# 66615         23624  b4d071ac-e355-461b-9a79-8bbb2e7155af
# 66616         15859  a8783334-0753-495e-b6bb-06e99e7edd84
#
#                                      lob_id  registrant_id  \
# 0      5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 1      5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 2      5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 3      5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 4      5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# ...                                     ...            ...
# 66612  292d333f-13df-5d2a-a231-7dfa64154c66           2194
# 66613  b433a883-f9f5-5f06-8407-7fc941cc8dac          11195
# 66614  d1d7627c-30db-5362-8c55-8be0b2b4d327          15042
# 66615  d1d7627c-30db-5362-8c55-8be0b2b4d327          15042
# 66616  3918db49-61e3-5f80-88eb-c14292cbae6d          11195
#
#                       registrant_name  filing_year filing_period_code  \
# 0                   STONINGTON GLOBAL         2021                 Q1
# 1                   STONINGTON GLOBAL         2021                 Q1
# 2                   STONINGTON GLOBAL         2021                 Q1
# 3                   STONINGTON GLOBAL         2021                 Q4
# 4                   STONINGTON GLOBAL         2021                 Q2
# ...                               ...          ...                ...
# 66612  AMERICAN DEFENSE INTERNATIONAL         2020                 Q2
# 66613         COVINGTON & BURLING LLP         2020                 Q1
# 66614             FOLEY & LARDNER LLP         2023                 Q2
# 66615             FOLEY & LARDNER LLP         2023                 Q3
# 66616         COVINGTON & BURLING LLP         2020                 Q1
#
#         amount  is_no_activity  is_self_filer  is_amendment  \
# 0      45000.0            True          False          True
# 1      45000.0            True          False          True
# 2      45000.0            True          False         False
# 3      45000.0            True          False         False
# 4      45000.0            True          False         False
# ...        ...             ...            ...           ...
# 66612      NaN            True          False         False
# 66613      NaN            True          False         False
# 66614      NaN            True          False         False
# 66615      NaN            True          False         False
# 66616      NaN            True          False         False
#
#                                               filing_url  \
# 0      https://lda.senate.gov/filings/public/filing/c...
# 1      https://lda.senate.gov/filings/public/filing/4...
# 2      https://lda.senate.gov/filings/public/filing/4...
# 3      https://lda.senate.gov/filings/public/filing/b...
# 4      https://lda.senate.gov/filings/public/filing/5...
# ...                                                  ...
# 66612  https://lda.senate.gov/filings/public/filing/e...
# 66613  https://lda.senate.gov/filings/public/filing/f...
# 66614  https://lda.senate.gov/filings/public/filing/a...
# 66615  https://lda.senate.gov/filings/public/filing/b...
# 66616  https://lda.senate.gov/filings/public/filing/a...
#
#                                   client_name
# 0              B & H FOTO & ELECTRONICS CORP.
# 1              B & H FOTO & ELECTRONICS CORP.
# 2              B & H FOTO & ELECTRONICS CORP.
# 3              B & H FOTO & ELECTRONICS CORP.
# 4              B & H FOTO & ELECTRONICS CORP.
# ...                                       ...
# 66612                      SENSIS CORPORATION
# 66613  ASSOCIATION OF EQUIPMENT MANUFACTURERS
# 66614                             DEPHY, INC.
# 66615                             DEPHY, INC.
# 66616                         UNITED AIRLINES
#
# [66617 rows x 13 columns]

# %%
duckdb.query("""
             select count(distinct report_uuid),count(distinct registrant_id),count(distinct lob_id), 'r' as src from lobbying_reports_r
   
             """)
# Out:
# ┌─────────────────────────────┬───────────────────────────────┬────────────────────────┬─────────┐
# │ count(DISTINCT report_uuid) │ count(DISTINCT registrant_id) │ count(DISTINCT lob_id) │   src   │
# │            int64            │             int64             │         int64          │ varchar │
# ├─────────────────────────────┼───────────────────────────────┼────────────────────────┼─────────┤
# │                       74181 │                           313 │                   4835 │ r       │
# └─────────────────────────────┴───────────────────────────────┴────────────────────────┴─────────┘

# %%
duckdb.query(""" 
             select count(distinct report_uuid),count(distinct registrant_id),count(distinct lob_id), 'c' as src from lobbying_reports_c
""")
# Out:
# ┌─────────────────────────────┬───────────────────────────────┬────────────────────────┬─────────┐
# │ count(DISTINCT report_uuid) │ count(DISTINCT registrant_id) │ count(DISTINCT lob_id) │   src   │
# │            int64            │             int64             │         int64          │ varchar │
# ├─────────────────────────────┼───────────────────────────────┼────────────────────────┼─────────┤
# │                       41939 │                           916 │                    465 │ c       │
# └─────────────────────────────┴───────────────────────────────┴────────────────────────┴─────────┘

# %%
merged
# Out:
#         littlesis_ID                           report_uuid  \
# 0             326262  c4fcfc56-f96d-4690-82ca-c4b744d73c71
# 1             326262  4777ae2d-f4f0-4117-bb46-7d783edfc628
# 2             326262  47334776-1188-4991-b854-406d9c1140de
# 3             326262  b3eaf19d-fe3e-456e-9f9d-e7ab38b95b22
# 4             326262  5a1dd3f9-c987-4f14-a64f-7f770b908a18
# ...              ...                                   ...
# 117283        217668  a82d39e7-139e-4f32-87af-9184736a1c81
# 117284        217668  6780c687-9e4a-4cc2-8869-45c5fc1af5bb
# 117285        217668  908bb8f5-ebd7-4e60-a839-fdf62c722367
# 117286        217668  2af4c71a-9140-44a1-a8e5-00e8f0013eb7
# 117287        217668  ffa4f7f2-ef66-4e6e-8794-54d4cfb33389
#
#                                       lob_id  registrant_id  \
# 0       5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 1       5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 2       5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 3       5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# 4       5aac59cf-27c1-5adb-b7df-dfc96b60123c      401105189
# ...                                      ...            ...
# 117283  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 117284  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 117285  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 117286  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
# 117287  cb4ac22a-dd82-5a42-a289-83fd13ba07d0      401104556
#
#                 registrant_name  filing_year filing_period_code   amount  \
# 0             STONINGTON GLOBAL         2021                 Q1  45000.0
# 1             STONINGTON GLOBAL         2021                 Q1  45000.0
# 2             STONINGTON GLOBAL         2021                 Q1  45000.0
# 3             STONINGTON GLOBAL         2021                 Q4  45000.0
# 4             STONINGTON GLOBAL         2021                 Q2  45000.0
# ...                         ...          ...                ...      ...
# 117283  BOUNDARY STONE PARTNERS         2022                 Q2  60000.0
# 117284  BOUNDARY STONE PARTNERS         2022                 Q3  60000.0
# 117285  BOUNDARY STONE PARTNERS         2023                 Q1      NaN
# 117286  BOUNDARY STONE PARTNERS         2022                 Q1      NaN
# 117287  BOUNDARY STONE PARTNERS         2022                 Q1      NaN
#
#         is_no_activity  is_self_filer  is_amendment  \
# 0                 True          False          True
# 1                 True          False          True
# 2                 True          False         False
# 3                 True          False         False
# 4                 True          False         False
# ...                ...            ...           ...
# 117283           False          False         False
# 117284           False          False         False
# 117285            True          False         False
# 117286           False          False          True
# 117287           False          False         False
#
#                                                filing_url  \
# 0       https://lda.senate.gov/filings/public/filing/c...
# 1       https://lda.senate.gov/filings/public/filing/4...
# 2       https://lda.senate.gov/filings/public/filing/4...
# 3       https://lda.senate.gov/filings/public/filing/b...
# 4       https://lda.senate.gov/filings/public/filing/5...
# ...                                                   ...
# 117283  https://lda.senate.gov/filings/public/filing/a...
# 117284  https://lda.senate.gov/filings/public/filing/6...
# 117285  https://lda.senate.gov/filings/public/filing/9...
# 117286  https://lda.senate.gov/filings/public/filing/2...
# 117287  https://lda.senate.gov/filings/public/filing/f...
#
#                            client_name
# 0       B & H FOTO & ELECTRONICS CORP.
# 1       B & H FOTO & ELECTRONICS CORP.
# 2       B & H FOTO & ELECTRONICS CORP.
# 3       B & H FOTO & ELECTRONICS CORP.
# 4       B & H FOTO & ELECTRONICS CORP.
# ...                                ...
# 117283                    STRIPE, INC.
# 117284                    STRIPE, INC.
# 117285                    STRIPE, INC.
# 117286                    STRIPE, INC.
# 117287                    STRIPE, INC.
#
# [117288 rows x 13 columns]

# %%
report_issues
# Out:
#                                  report_uuid general_issue_code  \
# 0       39fd84b3-5b25-4ba5-b5b6-dcc9d737470d                SMB
# 1       39fed6ab-97bf-408a-bbd3-fabd607bbe71                COM
# 2       39fed6ab-97bf-408a-bbd3-fabd607bbe71                CPI
# 3       39fed6ab-97bf-408a-bbd3-fabd607bbe71                CPT
# 4       39fed6ab-97bf-408a-bbd3-fabd607bbe71                DEF
# ...                                      ...                ...
# 234872  fff717c5-10d6-40e3-a8c9-92d45123d9ab                TAX
# 234873  fff717c5-10d6-40e3-a8c9-92d45123d9ab                EDU
# 234874  fff717c5-10d6-40e3-a8c9-92d45123d9ab                CPT
# 234875  fff717c5-10d6-40e3-a8c9-92d45123d9ab                IMM
# 234876  fffb4717-5daa-41b1-a794-6970a62800af                CIV
#
#                                  description bill_id_agg  \
# 0                             Small Business        None
# 1       Communications/Broadcasting/Radio/TV        None
# 2                          Computer Industry        None
# 3                 Copyright/Patent/Trademark        None
# 4                                    Defense        None
# ...                                      ...         ...
# 234872        Taxation/Internal Revenue Code        None
# 234873                             Education        None
# 234874            Copyright/Patent/Trademark        None
# 234875                           Immigration        None
# 234876          Civil Rights/Civil Liberties        None
#
#                                                issue_text
# 0                                              E-Commerce
# 1       S. 1260 - United States Innovation and Competi...
# 2       Government innovation; Innovation in the techn...
# 3                           Intellectual Property issues.
# 4       Issues related to government contracting; Nati...
# ...                                                   ...
# 234872                              Corporate tax reform.
# 234873                        Computer science education.
# 234874                                Patent legislation.
# 234875                   Immigration--high-skilled visas.
# 234876                                      Anti-Semitism
#
# [234877 rows x 5 columns]

# %%
report_issues.columns
# Out:
# Index(['report_uuid', 'general_issue_code', 'description', 'bill_id_agg',
#        'issue_text'],
#       dtype='object')
